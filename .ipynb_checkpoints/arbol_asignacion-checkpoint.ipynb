# %%
import pandas as pd
import numpy as np

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("out_tocones.csv", low_memory=False)
modelos = pd.read_excel("csvs/modelos.xlsx")

# %%
df
# Out:
#              id  anio_levantamiento  conglomerado  sitio condicion  \
# 0       2886174                2016         50760      1      Vivo
# 1       2886175                2016         50760      1      Vivo
# 2       2886176                2016         50760      1      Vivo
# 3       2886177                2016         50760      1      Vivo
# 4       2886178                2016         50760      1      Vivo
# ...         ...                 ...           ...    ...       ...
# 830745  3717500                2016         50303      1      Vivo
# 830746  3717501                2016         50303      2      Vivo
# 830747  3717502                2016         50303      2      Vivo
# 830748  3717503                2016         50303      2      Vivo
# 830749  3717504                2016         50303      2      Vivo
#
#         especie_id        familia       genero         epiteto  \
# 0              NaN      Malvaceae       Hampea       trilobata
# 1              NaN  Nyctaginaceae         Neea  psychotrioides
# 2              NaN       Fabaceae     Lysiloma    latisiliquum
# 3              NaN      Malvaceae       Luehea        speciosa
# 4              NaN     Sapotaceae  Sideroxylon    salicifolium
# ...            ...            ...          ...             ...
# 830745         NaN       Fabaceae  Caesalpinia       platyloba
# 830746         NaN       Fabaceae     Swartzia        cubensis
# 830747         NaN      Arecaceae        Sabal            yapa
# 830748         NaN     Sapotaceae    Manilkara          zapota
# 830749         NaN  Anacardiaceae     Metopium         brownei
#
#        categoria_infra infraespecie  numero_arbol  numero_tallo  tallos  \
# 0                  NaN          NaN            14          16.0     NaN
# 1                  NaN          NaN            21          23.0     NaN
# 2                  NaN          NaN            29          34.0     NaN
# 3                  NaN          NaN            35          40.0     NaN
# 4                  NaN          NaN            44          49.0     NaN
# ...                ...          ...           ...           ...     ...
# 830745             NaN          NaN             6           6.0     NaN
# 830746             NaN          NaN            12          13.0     NaN
# 830747             NaN          NaN            13          14.0     NaN
# 830748             NaN          NaN            24          25.0     NaN
# 830749             NaN          NaN             9          10.0     NaN
#
#         diametro  altura  is_predicted    latitud   longitud  \
# 0            8.3     6.4           0.0  20.622000 -87.336694
# 1           10.4     8.6           0.0  20.622000 -87.336694
# 2           32.8    10.3           0.0  20.622000 -87.336694
# 3            8.2     7.9           0.0  20.622000 -87.336694
# 4            9.8     6.8           0.0  20.622000 -87.336694
# ...          ...     ...           ...        ...        ...
# 830745      17.8     9.1           0.0  20.693639 -87.135167
# 830746       8.3     7.8           0.0  20.693639 -87.135167
# 830747      17.7    10.3           0.0  20.693639 -87.135167
# 830748      32.3     9.1           0.0  20.693639 -87.135167
# 830749       8.4     7.7           0.0  20.693639 -87.135167
#
#         clave_ecoregion_n2 clave_bur  referencia_1  referencia_2  user_id  \
# 0                     15.2       SMQ        493302            16      NaN
# 1                     15.2       SMQ        493309            23      NaN
# 2                     15.2       SMQ        493320            34      NaN
# 3                     15.2       SMQ        493326            40      NaN
# 4                     15.2       SMQ        493335            49      NaN
# ...                    ...       ...           ...           ...      ...
# 830745                15.2       SMQ        523099             6      NaN
# 830746                15.2       SMQ        523135            13      NaN
# 830747                15.2       SMQ        523136            14      NaN
# 830748                15.2       SMQ        523147            25      NaN
# 830749                15.2       SMQ        523132            10      NaN
#
#         created_at  updated_at  grado_putrefaccion  clave_ecoregion_n1  \
# 0              NaN         NaN                 NaN                  15
# 1              NaN         NaN                 NaN                  15
# 2              NaN         NaN                 NaN                  15
# 3              NaN         NaN                 NaN                  15
# 4              NaN         NaN                 NaN                  15
# ...            ...         ...                 ...                 ...
# 830745         NaN         NaN                 NaN                  15
# 830746         NaN         NaN                 NaN                  15
# 830747         NaN         NaN                 NaN                  15
# 830748         NaN         NaN                 NaN                  15
# 830749         NaN         NaN                 NaN                  15
#
#        clave_ecoregion_n3 clave_ecoregion_n4  estado_inegi        estado  edad
# 0                  15.2.2           15.2.2.2            23  Quintana Roo   NaN
# 1                  15.2.2           15.2.2.2            23  Quintana Roo   NaN
# 2                  15.2.2           15.2.2.2            23  Quintana Roo   NaN
# 3                  15.2.2           15.2.2.2            23  Quintana Roo   NaN
# 4                  15.2.2           15.2.2.2            23  Quintana Roo   NaN
# ...                   ...                ...           ...           ...   ...
# 830745             15.2.2           15.2.2.2            23  Quintana Roo   NaN
# 830746             15.2.2           15.2.2.2            23  Quintana Roo   NaN
# 830747             15.2.2           15.2.2.2            23  Quintana Roo   NaN
# 830748             15.2.2           15.2.2.2            23  Quintana Roo   NaN
# 830749             15.2.2           15.2.2.2            23  Quintana Roo   NaN
#
# [830750 rows x 33 columns]

# %%
df1 = pd.read_csv("csvs/arboles_2015.csv",low_memory=False)

# %%
modelos.head()
# Out:
#    id  id_anterior variable_resultado tipo                ecuacion  \
# 0   1          1.0                  b  NaN  (0.1649)*(d130^2.2755)
# 1   2          2.0                  b  NaN  Exp(-2.14)*(d130^2.23)
# 2   3          3.0                  b  NaN  Exp(-2.14)*(d130^2.23)
# 3   4          4.0                  b  NaN  Exp(-2.14)*(d130^2.23)
# 4   5          5.0                  b  NaN  Exp(-2.14)*(d130^2.23)
#
#                 ecuacion_php  especie_id     familia genero   epiteto  \
# 0  (0.1649)*([d130]**2.2755)         NaN  Betulaceae  Alnus    arguta
# 1  Exp(-2.14)*([d130]**2.23)         NaN  Betulaceae  Alnus  glabrata
# 2  Exp(-2.14)*([d130]**2.23)         NaN  Betulaceae  Alnus  glabrata
# 3  Exp(-2.14)*([d130]**2.23)         NaN  Betulaceae  Alnus       NaN
# 4  Exp(-2.14)*([d130]**2.23)         NaN  Betulaceae  Alnus       NaN
#
#   condicion     componente  diametro_min  diametro_max  numero_arboles  \
# 0      Vivo  Todo el árbol           6.2          45.0            22.0
# 1      Vivo  Todo el árbol           3.9          23.5            10.0
# 2      Vivo  Todo el árbol           3.9          23.5            10.0
# 3      Vivo  Todo el árbol           3.9          23.5            10.0
# 4      Vivo  Todo el árbol           3.9          23.5            10.0
#
#        r2  anio_publicacion  grado_putrefaccion  clave_ecoregion_n1  \
# 0  0.9677            2001.0                 NaN                 NaN
# 1  0.9700            2002.0                 NaN                14.0
# 2  0.9700            2002.0                 NaN                15.0
# 3  0.9700            2002.0                 NaN                14.0
# 4  0.9700            2002.0                 NaN                15.0
#
#    clave_ecoregion_n2 clave_ecoregion_n3 clave_ecoregion_n4 clave_bur  \
# 0                 NaN                NaN                NaN       NaN
# 1                14.5             14.5.1           14.5.1.2       NaN
# 2                15.3             15.3.1           15.3.1.1       NaN
# 3                14.5             14.5.1           14.5.1.2       NaN
# 4                15.3             15.3.1           15.3.1.1       NaN
#
#    clave_estado_inegi  activo  id_especie_mn  id_modelo_mn        referencia  \
# 0                 NaN       1            NaN         329.0  Ecuaciones Rojas
# 1                 NaN       1        17201.0          13.0  Ecuaciones Rojas
# 2                 NaN       1        17201.0          13.0  Ecuaciones Rojas
# 3                 NaN       1        17201.0          13.0  Ecuaciones Rojas
# 4                 NaN       1        17201.0          13.0  Ecuaciones Rojas
#
#    id_referencia notas
# 0            1.0   NaN
# 1            3.0   NaN
# 2            3.0   NaN
# 3            4.0   NaN
# 4            4.0   NaN

# %%
df.is_predicted.value_counts()
# Out:
# is_predicted
# 0.0    809968
# 2.0     13718
# 1.0      7064
# Name: count, dtype: int64

# %%
df.id.isnull().any()
# Out:
# np.False_

# %% [markdown]
# # normalizacion

# %%
df[(df.condicion == "Tocón") & (df.altura <= 0)]
# Out:
#              id  anio_levantamiento  conglomerado  sitio condicion  \
# 116     2886290                2019         75163      4     Tocón
# 130     2886304                2016         50545      1     Tocón
# 131     2886305                2016         50545      1     Tocón
# 225     2886399                2016         50078      1     Tocón
# 226     2886400                2016         50078      1     Tocón
# ...         ...                 ...           ...    ...       ...
# 830448  3717203                2015         50197      2     Tocón
# 830530  3717285                2016         75151      3     Tocón
# 830538  3717293                2019         49821      4     Tocón
# 830595  3717350                2016         50148      2     Tocón
# 830628  3717383                2017         50179      1     Tocón
#
#         especie_id                 familia                 genero  \
# 116            NaN  ZZ Familia Desconocida  ZZ Genero Desconocido
# 130            NaN                Fagaceae                Quercus
# 131            NaN                Fagaceae                Quercus
# 225            NaN  ZZ Familia Desconocida  ZZ Genero Desconocido
# 226            NaN  ZZ Familia Desconocida  ZZ Genero Desconocido
# ...            ...                     ...                    ...
# 830448         NaN                Fagaceae                Quercus
# 830530         NaN  ZZ Familia Desconocida  ZZ Genero Desconocido
# 830538         NaN  ZZ Familia Desconocida  ZZ Genero Desconocido
# 830595         NaN  ZZ Familia Desconocida  ZZ Genero Desconocido
# 830628         NaN  ZZ Familia Desconocida  ZZ Genero Desconocido
#
#               epiteto categoria_infra infraespecie  numero_arbol  \
# 116               NaN             NaN          NaN             3
# 130     magnoliifolia             NaN          NaN            10
# 131     magnoliifolia             NaN          NaN            13
# 225               NaN             NaN          NaN             1
# 226               NaN             NaN          NaN             5
# ...               ...             ...          ...           ...
# 830448         rugosa             NaN          NaN             2
# 830530            NaN             NaN          NaN             7
# 830538            NaN             NaN          NaN            26
# 830595            NaN             NaN          NaN             3
# 830628            NaN             NaN          NaN            23
#
#         numero_tallo  tallos  diametro  altura  is_predicted    latitud  \
# 116              3.0     NaN      13.0    0.40           0.0  16.658000
# 130             10.0     NaN      36.5     NaN           0.0  21.302167
# 131             13.0     NaN      13.2    0.31           0.0  21.302167
# 225              1.0     NaN      13.8     NaN           0.0  21.387500
# 226              5.0     NaN      11.8     NaN           0.0  21.387500
# ...              ...     ...       ...     ...           ...        ...
# 830448           2.0     NaN      12.5    0.50           0.0  21.394111
# 830530           7.0     NaN      39.1     NaN           0.0  16.677333
# 830538          26.0     NaN      25.5    0.40           0.0  20.866306
# 830595          12.0     NaN      22.7    0.40           0.0  21.417778
# 830628          24.0     NaN      54.3    0.37           0.0  21.406944
#
#           longitud  clave_ecoregion_n2 clave_bur  referencia_1  referencia_2  \
# 116     -96.623583                14.4        BQ        857537             3
# 130    -104.766583                13.4       BQP        475352            10
# 131    -104.766583                13.4       BQP        475355            13
# 225    -105.058917                15.5       SMQ        521110             1
# 226    -105.058917                15.5       SMQ        521114             5
# ...            ...                 ...       ...           ...           ...
# 830448  -99.293306                13.3        BQ        246211             2
# 830530  -97.184944                13.5        BP        523384             7
# 830538  -87.989278                15.2       SMS        859238            26
# 830595 -101.667278                12.2       BQP        521231            12
# 830628 -100.165333                13.3       BQP        654372            24
#
#         user_id  created_at  updated_at  grado_putrefaccion  \
# 116         NaN         NaN         NaN                 2.0
# 130         NaN         NaN         NaN                 3.0
# 131         NaN         NaN         NaN                 3.0
# 225         NaN         NaN         NaN                 2.0
# 226         NaN         NaN         NaN                 2.0
# ...         ...         ...         ...                 ...
# 830448      NaN         NaN         NaN                 NaN
# 830530      NaN         NaN         NaN                 4.0
# 830538      NaN         NaN         NaN                 4.0
# 830595      NaN         NaN         NaN                 3.0
# 830628      NaN         NaN         NaN                 3.0
#
#         clave_ecoregion_n1 clave_ecoregion_n3 clave_ecoregion_n4  \
# 116                     14             14.4.3           14.4.3.3
# 130                     13             13.4.2           13.4.2.2
# 131                     13             13.4.2           13.4.2.2
# 225                     15             15.5.2           15.5.2.2
# 226                     15             15.5.2           15.5.2.2
# ...                    ...                ...                ...
# 830448                  13             13.3.1           13.3.1.1
# 830530                  13             13.5.2           13.5.2.1
# 830538                  15             15.2.1           15.2.1.1
# 830595                  12             12.2.1           12.2.1.2
# 830628                  13             13.3.1           13.3.1.1
#
#         estado_inegi      estado  edad
# 116               20      Oaxaca   NaN
# 130               18     Nayarit   NaN
# 131               18     Nayarit   NaN
# 225               18     Nayarit   NaN
# 226               18     Nayarit   NaN
# ...              ...         ...   ...
# 830448            22   Querétaro   NaN
# 830530            20      Oaxaca   NaN
# 830538            31     Yucatán   NaN
# 830595            14     Jalisco   NaN
# 830628            11  Guanajuato   NaN
#
# [14251 rows x 33 columns]

# %%
df.diametro[(df.condicion == "Vivo") & (df.diametro.isnull())] = 15
# Out:
# /tmp/ipykernel_14801/2660231379.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df.diametro[(df.condicion == "Vivo") & (df.diametro.isnull())] = 15
# /tmp/ipykernel_14801/2660231379.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.diametro[(df.condicion == "Vivo") & (df.diametro.isnull())] = 15

# %%
df.altura[(df.condicion == "Vivo") & (df.altura.isnull())]
# Out:
# Series([], Name: altura, dtype: float64)

# %%
df.altura[(df.condicion == "Muerto") & (df.altura.isnull())] = 2.8
# Out:
# /tmp/ipykernel_14801/110991496.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df.altura[(df.condicion == "Muerto") & (df.altura.isnull())] = 2.8
# /tmp/ipykernel_14801/110991496.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.altura[(df.condicion == "Muerto") & (df.altura.isnull())] = 2.8

# %%
df.diametro[(df.condicion == "Tocón") & (df.diametro.isnull())] = 10
# Out:
# /tmp/ipykernel_14801/1054066010.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df.diametro[(df.condicion == "Tocón") & (df.diametro.isnull())] = 10
# /tmp/ipykernel_14801/1054066010.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.diametro[(df.condicion == "Tocón") & (df.diametro.isnull())] = 10

# %%
df.diametro[(df.condicion == "Tocón") & (df.diametro.isnull())]
# Out:
# Series([], Name: diametro, dtype: float64)

# %%
df.loc[501115]
# Out:
# id                         3387622
# anio_levantamiento            2015
# conglomerado                 76944
# sitio                            2
# condicion                   Muerto
# especie_id                     NaN
# familia               Siparunaceae
# genero                    Siparuna
# epiteto                 thecaphora
# categoria_infra                NaN
# infraespecie                   NaN
# numero_arbol                     5
# numero_tallo                  10.0
# tallos                         NaN
# diametro                      15.5
# altura                         2.8
# is_predicted                   0.0
# latitud                   16.18925
# longitud                -97.438333
# clave_ecoregion_n2            13.5
# clave_bur                       BM
# referencia_1                 79069
# referencia_2                     5
# user_id                        NaN
# created_at                     NaN
# updated_at                     NaN
# grado_putrefaccion             NaN
# clave_ecoregion_n1              13
# clave_ecoregion_n3          13.5.2
# clave_ecoregion_n4        13.5.2.3
# estado_inegi                    20
# estado                      Oaxaca
# edad                           NaN
# Name: 501115, dtype: object

# %%
df[df.id == 2886304]
# Out:
#           id  anio_levantamiento  conglomerado  sitio condicion  especie_id  \
# 130  2886304                2016         50545      1     Tocón         NaN
#
#       familia   genero        epiteto categoria_infra infraespecie  \
# 130  Fagaceae  Quercus  magnoliifolia             NaN          NaN
#
#      numero_arbol  numero_tallo  tallos  diametro  altura  is_predicted  \
# 130            10          10.0     NaN      36.5     0.3           0.0
#
#        latitud    longitud  clave_ecoregion_n2 clave_bur  referencia_1  \
# 130  21.302167 -104.766583                13.4       BQP        475352
#
#      referencia_2  user_id  created_at  updated_at  grado_putrefaccion  \
# 130            10      NaN         NaN         NaN                 3.0
#
#      clave_ecoregion_n1 clave_ecoregion_n3 clave_ecoregion_n4  estado_inegi  \
# 130                  13             13.4.2           13.4.2.2            18
#
#       estado  edad
# 130  Nayarit   NaN

# %%
df.diametro[(df.diametro.isnull())]
# Out:
# Series([], Name: diametro, dtype: float64)

# %%
df.altura[(df.altura.isnull())]
# Out:
# Series([], Name: altura, dtype: float64)

# %% [markdown]
# # densidad

# %%
conditions_den = [
    (lambda df,row: df[(df.genero == row.genero) & (df.epiteto == row.epiteto)]),
    (lambda df,row: df[(df.genero == row.genero) & (df.epiteto.isnull())]),
    (lambda df,row: df[(df.genero == row.genero)]),
    (lambda df,row: df[df.clave_ecoregion_n2 == row.clave_ecoregion_n2]) 
]

# %%
n = len(df)

# %%
equations = modelos[modelos.variable_resultado == "p"]

# %%
p_eq = np.empty(n, dtype=object)

# %%
for index, row in df.iterrows():
    flag = False
    for eq in  conditions_den:
        equation_df = eq(equations, row)    
        if not equation_df.empty:
            p_eq[index] = equation_df.iloc[0,5]
            flag = True
            break
    if not flag:
        print(index)
# Out:
# 53280
# 58254
# 61677

# %%
p_eq
# Out:
# array(['0.35341', '0.314', '0.53441', ..., '0.61222', '0.79789',
#        '0.61789'], dtype=object)

# %%
df.iloc[53280]
# Out:
# id                                            2939461
# anio_levantamiento                               2015
# conglomerado                                    51860
# sitio                                               2
# condicion                                      Muerto
# especie_id                                        NaN
# familia                        ZZ Familia Desconocida
# genero                          ZZ Genero Desconocido
# epiteto                                           NaN
# categoria_infra                                   NaN
# infraespecie                                      NaN
# numero_arbol                                        2
# numero_tallo                                      3.0
# tallos                                            NaN
# diametro                                          9.6
# altura                                            5.8
# is_predicted                                      0.0
# latitud                                     21.030306
# longitud                                   -97.367194
# clave_ecoregion_n2                                0.0
# clave_bur                                          VM
# referencia_1                                    57396
# referencia_2                                        2
# user_id                                           NaN
# created_at                                        NaN
# updated_at                                        NaN
# grado_putrefaccion                                NaN
# clave_ecoregion_n1                                  0
# clave_ecoregion_n3                                NaN
# clave_ecoregion_n4                                NaN
# estado_inegi                                       30
# estado                Veracruz de Ignacio de la Llave
# edad                                              NaN
# Name: 53280, dtype: object

# %%
equation_df
# Out:
#         id  id_anterior variable_resultado tipo ecuacion ecuacion_php  \
# 2862  2863       2847.0                  p  NaN  0.55677      0.55677
#
#       especie_id familia genero epiteto condicion     componente  \
# 2862         NaN     NaN    NaN     NaN     Todos  Todo el árbol
#
#       diametro_min  diametro_max  numero_arboles   r2  anio_publicacion  \
# 2862           NaN           NaN             NaN  0.0               NaN
#
#       grado_putrefaccion  clave_ecoregion_n1  clave_ecoregion_n2  \
# 2862                 NaN                 NaN                13.4
#
#      clave_ecoregion_n3 clave_ecoregion_n4 clave_bur  clave_estado_inegi  \
# 2862                NaN                NaN       NaN                 NaN
#
#       activo  id_especie_mn  id_modelo_mn referencia  id_referencia notas
# 2862       1            NaN       50389.0      SEByC        50389.0   NaN

# %%
equation_df.iloc[0,5]
# Out:
# '0.55677'

# %%
df.loc[53275]
# Out:
# id                                            2939461
# anio_levantamiento                               2015
# conglomerado                                    51860
# sitio                                               2
# condicion                                      Muerto
# especie_id                                        NaN
# familia                        ZZ Familia Desconocida
# genero                          ZZ Genero Desconocido
# epiteto                                           NaN
# categoria_infra                                   NaN
# infraespecie                                      NaN
# numero_arbol                                        2
# numero_tallo                                      3.0
# tallos                                            NaN
# diametro                                          9.6
# altura                                            5.8
# is_predicted                                      0.0
# latitud                                     21.030306
# longitud                                   -97.367194
# clave_ecoregion_n2                                0.0
# clave_bur                                          VM
# referencia_1                                    57396
# referencia_2                                        2
# user_id                                           NaN
# created_at                                        NaN
# updated_at                                        NaN
# grado_putrefaccion                                NaN
# clave_ecoregion_n1                                  0
# clave_ecoregion_n3                                NaN
# clave_ecoregion_n4                                NaN
# estado_inegi                                       30
# estado                Veracruz de Ignacio de la Llave
# edad                                              NaN
# Name: 53275, dtype: object

# %% [markdown]
# # biomasa

# %%
conditions_bio = [

            
            lambda df, row: df[(df.genero == row.genero) & (df.epiteto == row.epiteto) 
                    & (df.clave_ecoregion_n2 == row.clave_ecoregion_n2) & (df.clave_bur == row.clave_bur) 
                    & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],   
    
            lambda df, row: df[(df.genero == row.genero) & (df.epiteto == row.epiteto) 
                    & (df.clave_ecoregion_n2 == row.clave_ecoregion_n2) 
                    & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],  
    
            lambda df, row: df[(df.genero == row.genero) & (df.epiteto == row.epiteto)
                    & (df.clave_bur == row.clave_bur) 
                    & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],
    
            lambda df, row: df[(df.genero == row.genero) & (df.epiteto == row.epiteto) 
                    & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],

    
    
            lambda df, row: df[(df.genero == row.genero) & (df.epiteto.isnull()) 
                    & (df.clave_ecoregion_n2 == row.clave_ecoregion_n2) & (df.clave_bur == row.clave_bur) 
                    & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],
    
            lambda df, row: df[(df.genero == row.genero) & (df.epiteto.isnull()) 
                    & (df.clave_ecoregion_n2 == row.clave_ecoregion_n2) 
                    & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],
    
            lambda df, row: df[(df.genero == row.genero) & (df.epiteto.isnull())
                    & (df.clave_bur == row.clave_bur)
                    & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],
    
            lambda df, row: df[(df.genero == row.genero) & (df.epiteto.isnull()) 
                    & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],



    
    
            lambda df, row: df[(df.genero == row.genero) 
                    & (df.clave_ecoregion_n2 == row.clave_ecoregion_n2) & (df.clave_bur == row.clave_bur) 
                    & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],
    
            lambda df, row: df[(df.genero == row.genero)
                    & (df.clave_ecoregion_n2 == row.clave_ecoregion_n2)                 
                    & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],
    
            lambda df, row: df[(df.genero == row.genero)
                    & (df.clave_bur == row.clave_bur)
                    & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],
    
            lambda df, row: df[(df.genero == row.genero)
                    & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],

    

    
            lambda df, row: df[(df.clave_ecoregion_n2 == row.clave_ecoregion_n2)
                    & (df.clave_bur == row.clave_bur)
                    & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],
    
            lambda df, row: df[(df.clave_ecoregion_n2 == row.clave_ecoregion_n2)
                    & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],
    
            lambda df, row: df[(df.clave_bur == row.clave_bur)
                    & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],

    
            
            
            lambda df, row: df[(df.condicion == "Vivo")
                    & (df.tipo == "General")],
            lambda df, row: df[(df.condicion == "Muerto")
                    & (df.tipo == "General")]
            ]

# %%
equations = modelos[(modelos.variable_resultado == "b") & (modelos.activo ==1)]

# %%
equations[(equations.condicion == "Vivo") & (equations.tipo == "General")]
# Out:
#       id  id_anterior variable_resultado     tipo  \
# 455  456        440.0                  b  General
# 456  457        441.0                  b  General
# 457  458        442.0                  b  General
# 458  459        443.0                  b  General
# 459  460        444.0                  b  General
# ..   ...          ...                ...      ...
# 556  557        541.0                  b  General
# 557  558        542.0                  b  General
# 558  559        543.0                  b  General
# 559  560        544.0                  b  General
# 560  561        545.0                  b  General
#
#                                             ecuacion  \
# 455  (Exp(-2.187+(0.916*(LN((p)*((d130)^2)*(ht))))))
# 456  (Exp(-2.187+(0.916*(LN((p)*((d130)^2)*(ht))))))
# 457  (Exp(-2.187+(0.916*(LN((p)*((d130)^2)*(ht))))))
# 458  (Exp(-2.187+(0.916*(LN((p)*((d130)^2)*(ht))))))
# 459  (Exp(-2.187+(0.916*(LN((p)*((d130)^2)*(ht))))))
# ..                                               ...
# 556            (Exp(-2.977+LN((p)*((d130)^2)*(ht))))
# 557            (Exp(-2.977+LN((p)*((d130)^2)*(ht))))
# 558            (Exp(-2.977+LN((p)*((d130)^2)*(ht))))
# 559            (Exp(-2.977+LN((p)*((d130)^2)*(ht))))
# 560            (Exp(-2.977+LN((p)*((d130)^2)*(ht))))
#
#                                           ecuacion_php  especie_id familia  \
# 455  (Exp(-2.187+(0.916*(LOG(([p])*(([d130])**2)*([...         NaN     NaN
# 456  (Exp(-2.187+(0.916*(LOG(([p])*(([d130])**2)*([...         NaN     NaN
# 457  (Exp(-2.187+(0.916*(LOG(([p])*(([d130])**2)*([...         NaN     NaN
# 458  (Exp(-2.187+(0.916*(LOG(([p])*(([d130])**2)*([...         NaN     NaN
# 459  (Exp(-2.187+(0.916*(LOG(([p])*(([d130])**2)*([...         NaN     NaN
# ..                                                 ...         ...     ...
# 556      (Exp(-2.977+LOG(([p])*(([d130])**2)*([ht]))))         NaN     NaN
# 557      (Exp(-2.977+LOG(([p])*(([d130])**2)*([ht]))))         NaN     NaN
# 558      (Exp(-2.977+LOG(([p])*(([d130])**2)*([ht]))))         NaN     NaN
# 559      (Exp(-2.977+LOG(([p])*(([d130])**2)*([ht]))))         NaN     NaN
# 560      (Exp(-2.977+LOG(([p])*(([d130])**2)*([ht]))))         NaN     NaN
#
#     genero epiteto condicion     componente  diametro_min  diametro_max  \
# 455    NaN     NaN      Vivo  Todo el árbol           NaN           NaN
# 456    NaN     NaN      Vivo  Todo el árbol           NaN           NaN
# 457    NaN     NaN      Vivo  Todo el árbol           NaN           NaN
# 458    NaN     NaN      Vivo  Todo el árbol           NaN           NaN
# 459    NaN     NaN      Vivo  Todo el árbol           NaN           NaN
# ..     ...     ...       ...            ...           ...           ...
# 556    NaN     NaN      Vivo  Todo el árbol           NaN           NaN
# 557    NaN     NaN      Vivo  Todo el árbol           NaN           NaN
# 558    NaN     NaN      Vivo  Todo el árbol           NaN           NaN
# 559    NaN     NaN      Vivo  Todo el árbol           NaN           NaN
# 560    NaN     NaN      Vivo  Todo el árbol           NaN           NaN
#
#      numero_arboles  r2  anio_publicacion  grado_putrefaccion  \
# 455             NaN NaN               NaN                 NaN
# 456             NaN NaN               NaN                 NaN
# 457             NaN NaN               NaN                 NaN
# 458             NaN NaN               NaN                 NaN
# 459             NaN NaN               NaN                 NaN
# ..              ...  ..               ...                 ...
# 556             NaN NaN               NaN                 NaN
# 557             NaN NaN               NaN                 NaN
# 558             NaN NaN               NaN                 NaN
# 559             NaN NaN               NaN                 NaN
# 560             NaN NaN               NaN                 NaN
#
#      clave_ecoregion_n1  clave_ecoregion_n2 clave_ecoregion_n3  \
# 455                 9.0                9.50              9.5.1
# 456                 9.0                9.60              9.6.1
# 457                 9.0                9.60              9.6.1
# 458                 9.0                9.99               9.99
# 459                10.0               10.20             10.2.2
# ..                  ...                 ...                ...
# 556                15.0               15.10             15.1.2
# 557                15.0               15.20             15.2.2
# 558                15.0               15.50             15.5.1
# 559                15.0               15.50             15.5.2
# 560                15.0               15.60             15.6.1
#
#     clave_ecoregion_n4 clave_bur  clave_estado_inegi  activo  id_especie_mn  \
# 455            9.5.1.2       NaN                 NaN       1            NaN
# 456            9.6.1.1       NaN                 NaN       1            NaN
# 457            9.6.1.2       NaN                 NaN       1            NaN
# 458               9.99       NaN                 NaN       1            NaN
# 459           10.2.2.5       NaN                 NaN       1            NaN
# ..                 ...       ...                 ...     ...            ...
# 556           15.1.2.1       NaN                 NaN       1            NaN
# 557           15.2.2.1       NaN                 NaN       1            NaN
# 558           15.5.1.1       NaN                 NaN       1            NaN
# 559           15.5.2.1       NaN                 NaN       1            NaN
# 560           15.6.1.1       NaN                 NaN       1            NaN
#
#      id_modelo_mn        referencia  id_referencia notas
# 455           NaN  Ecuaciones Chave            1.0   NaN
# 456           NaN  Ecuaciones Chave            1.0   NaN
# 457           NaN  Ecuaciones Chave            1.0   NaN
# 458           NaN  Ecuaciones Chave            1.0   NaN
# 459           NaN  Ecuaciones Chave            1.0   NaN
# ..            ...               ...            ...   ...
# 556           NaN  Ecuaciones Chave           10.0   NaN
# 557           NaN  Ecuaciones Chave           10.0   NaN
# 558           NaN  Ecuaciones Chave           10.0   NaN
# 559           NaN  Ecuaciones Chave           10.0   NaN
# 560           NaN  Ecuaciones Chave           10.0   NaN
#
# [104 rows x 30 columns]

# %%
df_vivo = df[df.condicion == "Vivo"]

# %%
b_eq = np.empty(n, dtype=object)

# %%
for index, row in df_vivo.iterrows():
    flag = False
    for eq  in conditions_bio:
        equation_df = eq(equations, row)    
        if not equation_df.empty:
            b_eq[index] = equation_df.iloc[0,5]
            flag = True
            break
    if not flag:
        print(index)

# %%
b_eq[13]

# %%
df_muerto = df[df.condicion == "Muerto"]
df_tocon = df[df.condicion == "Tocón"]

# %%
for index, row in df_muerto.iterrows():
    b_eq[index] = modelos.iloc[2886,5]

# %%
for index, row in df_tocon.iterrows():
    b_eq[index] = modelos.iloc[2889,5]

# %%
df_muerto.grado_putrefaccion.value_counts()
# Out:
# grado_putrefaccion
# 2.0    16
# 3.0    12
# 1.0     6
# Name: count, dtype: int64

# %%
modelos.iloc[2889,5]
# Out:
# '1000 * ([p] * [v])*(3/6)'

# %%
equation_df
# Out:
#       id  id_anterior variable_resultado     tipo  \
# 455  456        440.0                  b  General
# 456  457        441.0                  b  General
# 457  458        442.0                  b  General
# 458  459        443.0                  b  General
# 459  460        444.0                  b  General
# ..   ...          ...                ...      ...
# 556  557        541.0                  b  General
# 557  558        542.0                  b  General
# 558  559        543.0                  b  General
# 559  560        544.0                  b  General
# 560  561        545.0                  b  General
#
#                                             ecuacion  \
# 455  (Exp(-2.187+(0.916*(LN((p)*((d130)^2)*(ht))))))
# 456  (Exp(-2.187+(0.916*(LN((p)*((d130)^2)*(ht))))))
# 457  (Exp(-2.187+(0.916*(LN((p)*((d130)^2)*(ht))))))
# 458  (Exp(-2.187+(0.916*(LN((p)*((d130)^2)*(ht))))))
# 459  (Exp(-2.187+(0.916*(LN((p)*((d130)^2)*(ht))))))
# ..                                               ...
# 556            (Exp(-2.977+LN((p)*((d130)^2)*(ht))))
# 557            (Exp(-2.977+LN((p)*((d130)^2)*(ht))))
# 558            (Exp(-2.977+LN((p)*((d130)^2)*(ht))))
# 559            (Exp(-2.977+LN((p)*((d130)^2)*(ht))))
# 560            (Exp(-2.977+LN((p)*((d130)^2)*(ht))))
#
#                                           ecuacion_php  especie_id familia  \
# 455  (Exp(-2.187+(0.916*(LOG(([p])*(([d130])**2)*([...         NaN     NaN
# 456  (Exp(-2.187+(0.916*(LOG(([p])*(([d130])**2)*([...         NaN     NaN
# 457  (Exp(-2.187+(0.916*(LOG(([p])*(([d130])**2)*([...         NaN     NaN
# 458  (Exp(-2.187+(0.916*(LOG(([p])*(([d130])**2)*([...         NaN     NaN
# 459  (Exp(-2.187+(0.916*(LOG(([p])*(([d130])**2)*([...         NaN     NaN
# ..                                                 ...         ...     ...
# 556      (Exp(-2.977+LOG(([p])*(([d130])**2)*([ht]))))         NaN     NaN
# 557      (Exp(-2.977+LOG(([p])*(([d130])**2)*([ht]))))         NaN     NaN
# 558      (Exp(-2.977+LOG(([p])*(([d130])**2)*([ht]))))         NaN     NaN
# 559      (Exp(-2.977+LOG(([p])*(([d130])**2)*([ht]))))         NaN     NaN
# 560      (Exp(-2.977+LOG(([p])*(([d130])**2)*([ht]))))         NaN     NaN
#
#     genero epiteto condicion     componente  diametro_min  diametro_max  \
# 455    NaN     NaN      Vivo  Todo el árbol           NaN           NaN
# 456    NaN     NaN      Vivo  Todo el árbol           NaN           NaN
# 457    NaN     NaN      Vivo  Todo el árbol           NaN           NaN
# 458    NaN     NaN      Vivo  Todo el árbol           NaN           NaN
# 459    NaN     NaN      Vivo  Todo el árbol           NaN           NaN
# ..     ...     ...       ...            ...           ...           ...
# 556    NaN     NaN      Vivo  Todo el árbol           NaN           NaN
# 557    NaN     NaN      Vivo  Todo el árbol           NaN           NaN
# 558    NaN     NaN      Vivo  Todo el árbol           NaN           NaN
# 559    NaN     NaN      Vivo  Todo el árbol           NaN           NaN
# 560    NaN     NaN      Vivo  Todo el árbol           NaN           NaN
#
#      numero_arboles  r2  anio_publicacion  grado_putrefaccion  \
# 455             NaN NaN               NaN                 NaN
# 456             NaN NaN               NaN                 NaN
# 457             NaN NaN               NaN                 NaN
# 458             NaN NaN               NaN                 NaN
# 459             NaN NaN               NaN                 NaN
# ..              ...  ..               ...                 ...
# 556             NaN NaN               NaN                 NaN
# 557             NaN NaN               NaN                 NaN
# 558             NaN NaN               NaN                 NaN
# 559             NaN NaN               NaN                 NaN
# 560             NaN NaN               NaN                 NaN
#
#      clave_ecoregion_n1  clave_ecoregion_n2 clave_ecoregion_n3  \
# 455                 9.0                9.50              9.5.1
# 456                 9.0                9.60              9.6.1
# 457                 9.0                9.60              9.6.1
# 458                 9.0                9.99               9.99
# 459                10.0               10.20             10.2.2
# ..                  ...                 ...                ...
# 556                15.0               15.10             15.1.2
# 557                15.0               15.20             15.2.2
# 558                15.0               15.50             15.5.1
# 559                15.0               15.50             15.5.2
# 560                15.0               15.60             15.6.1
#
#     clave_ecoregion_n4 clave_bur  clave_estado_inegi  activo  id_especie_mn  \
# 455            9.5.1.2       NaN                 NaN       1            NaN
# 456            9.6.1.1       NaN                 NaN       1            NaN
# 457            9.6.1.2       NaN                 NaN       1            NaN
# 458               9.99       NaN                 NaN       1            NaN
# 459           10.2.2.5       NaN                 NaN       1            NaN
# ..                 ...       ...                 ...     ...            ...
# 556           15.1.2.1       NaN                 NaN       1            NaN
# 557           15.2.2.1       NaN                 NaN       1            NaN
# 558           15.5.1.1       NaN                 NaN       1            NaN
# 559           15.5.2.1       NaN                 NaN       1            NaN
# 560           15.6.1.1       NaN                 NaN       1            NaN
#
#      id_modelo_mn        referencia  id_referencia notas
# 455           NaN  Ecuaciones Chave            1.0   NaN
# 456           NaN  Ecuaciones Chave            1.0   NaN
# 457           NaN  Ecuaciones Chave            1.0   NaN
# 458           NaN  Ecuaciones Chave            1.0   NaN
# 459           NaN  Ecuaciones Chave            1.0   NaN
# ..            ...               ...            ...   ...
# 556           NaN  Ecuaciones Chave           10.0   NaN
# 557           NaN  Ecuaciones Chave           10.0   NaN
# 558           NaN  Ecuaciones Chave           10.0   NaN
# 559           NaN  Ecuaciones Chave           10.0   NaN
# 560           NaN  Ecuaciones Chave           10.0   NaN
#
# [104 rows x 30 columns]

# %%
b_eq
# Out:
# array(['(Exp(-2.187+(0.916*(LOG(([p])*(([d130])**2)*([ht]))))))',
#        '(Exp(-2.187+(0.916*(LOG(([p])*(([d130])**2)*([ht]))))))',
#        'Exp(-1.852)*([d130]**2.378)', ...,
#        '(Exp(-2.187+(0.916*(LOG(([p])*(([d130])**2)*([ht]))))))',
#        '(Exp(-2.187+(0.916*(LOG(([p])*(([d130])**2)*([ht]))))))',
#        '(Exp(-2.187+(0.916*(LOG(([p])*(([d130])**2)*([ht]))))))'],
#       dtype=object)

# %%
np.save('b_eq.npy', b_eq)

# %%
np.save('p_eq.npy', p_eq)

# %%
df.density_equation.value_counts()

# %%
a

# %% [markdown]
# # asignacion carbono

# %%
conditions_eq_2 = [
    lambda df, row: df[(df.genero == row.genero) & (df.epiteto == row.epiteto) 
        & (df.clave_ecoregion_n2 == row.clave_ecoregion_n2) & (df.clave_bur == row.clave_bur) 
        & (df.diametro_min >= row.diametro) & (df.diametro_max >= row.diametro)],

    lambda df, row: df[(df.genero == row.genero) & (df.epiteto == row.epiteto) 
        & (df.clave_ecoregion_n2 == row.clave_ecoregion_n2) 
        & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],

    lambda df, row: df[(df.genero == row.genero) & (df.epiteto == row.epiteto) 
        & (df.clave_bur == row.clave_bur) 
        & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],

    lambda df, row: df[(df.genero == row.genero) & (df.epiteto == row.epiteto) 
        & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],

    lambda df, row: df[(df.genero == row.genero) & (df.epiteto.isnull()) 
        & (df.clave_ecoregion_n2 == row.clave_ecoregion_n2) & (df.clave_bur == row.clave_bur) 
        & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],

    lambda df, row: df[(df.genero == row.genero) & (df.epiteto.isnull()) 
        & (df.clave_ecoregion_n2 == row.clave_ecoregion_n2) 
        & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],

    lambda df, row: df[(df.genero == row.genero) & (df.epiteto.isnull()) 
        & (df.clave_bur == row.clave_bur) 
        & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],

    lambda df, row: df[(df.genero == row.genero) & (df.epiteto.isnull()) 
        & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],

    lambda df, row: df[(df.genero == row.genero) 
        & (df.clave_ecoregion_n2 == row.clave_ecoregion_n2) & (df.clave_bur == row.clave_bur) 
        & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],

    lambda df, row: df[(df.genero == row.genero)
        & (df.clave_ecoregion_n2 == row.clave_ecoregion_n2) 
        & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],

    lambda df, row: df[(df.genero == row.genero) 
        & (df.clave_bur == row.clave_bur) 
        & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],

    lambda df, row: df[(df.genero == row.genero) 
        & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],

    lambda df, row: df[(df.genero == row.genero) & (df.epiteto == row.epiteto) 
        & (df.diametro_min.isnull()) & (df.diametro_max.isnull())],

    lambda df, row: df[(df.genero == row.genero) & (df.epiteto.isnull()) 
        & (df.diametro_min.isnull()) & (df.diametro_max.isnull())],

    lambda df, row: df[(df.genero == row.genero)
        & (df.diametro_min.isnull()) & (df.diametro_max.isnull())],

    lambda df, row: df[(df.familia == row.familia) & (df.genero.isnull()) 
        & (df.epiteto.isnull())],

    lambda df, row: df[(df.clave_ecoregion_n2 == row.clave_ecoregion_n2) 
        & (df.clave_bur == row.clave_bur) 
        & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],

    lambda df, row: df[(df.clave_ecoregion_n2 == row.clave_ecoregion_n2) 
        & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],

    lambda df, row: df[(df.clave_bur == row.clave_bur) 
        & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],

    lambda df, row: df[(df.clave_ecoregion_n2 == row.clave_ecoregion_n2) 
        & (df.clave_bur == row.clave_bur) 
        & (df.diametro_min.isnull()) & (df.diametro_max.isnull())],

    lambda df, row: df[(df.clave_ecoregion_n2 == row.clave_ecoregion_n2) 
        & (df.diametro_min.isnull()) & (df.diametro_max.isnull())],

    lambda df, row: df[(df.clave_bur == row.clave_bur) 
        & (df.diametro_min.isnull()) & (df.diametro_max.isnull())],

    lambda df, row: df[(df.id == 998)]
]

# %%
equations = modelos[(modelos.variable_resultado == "c") & (modelos.activo ==1)]

# %%
c_eq = np.empty(n, dtype=object)

# %%
998
# Out:
# 998

# %%
equations[equations.id == 998]
# Out:
#       id  id_anterior variable_resultado     tipo ecuacion ecuacion_php  \
# 702  998        982.0                  c  General  b*0.447    [b]*0.447
#
#      especie_id familia genero epiteto condicion     componente  diametro_min  \
# 702         NaN     NaN    NaN     NaN     Todos  Todo el árbol           NaN
#
#      diametro_max  numero_arboles  r2  anio_publicacion  grado_putrefaccion  \
# 702           NaN             NaN NaN            2017.0                 NaN
#
#      clave_ecoregion_n1  clave_ecoregion_n2 clave_ecoregion_n3  \
# 702                 NaN                 NaN                NaN
#
#     clave_ecoregion_n4 clave_bur  clave_estado_inegi  activo  id_especie_mn  \
# 702                NaN       NaN                 NaN       1            NaN
#
#      id_modelo_mn referencia  id_referencia                        notas
# 702           NaN      SEByC            NaN  Fracción General de carbono

# %%
start_time = time.time()
for index, row in df.iterrows():
    for  eq  in conditions_eq_2:
        equation_df = eq(equations, row)    
        if not equation_df.empty:
            c_eq[index] = equation_df.iloc[0,5]
            break
end_time = time.time()

# Calculate elapsed time
elapsed_time = end_time - start_time
print(f"Task took {elapsed_time:.6f} seconds.")
# Out:
# Task took 2213.593348 seconds.

# %%
c_eq
# Out:
# array(['[b]*0.43', '[b]*0.447', '(0.4709*[b])', ..., None, None, None],
#       dtype=object)

# %%
c_eq
# Out:
# array(['[b]*0.43', '[b]*0.447', '(0.4709*[b])', ..., '[b]*0.4',
#        '(0.4789*[b])', '(0.4974*[b])'], dtype=object)

# %%
np.save('c_eq.npy', c_eq)

# %% [markdown]
# # calculo volumen

# %%
conditions_eq_3 = [
    # Especie + ecoregión + clave BUR + rango diamétrico
    lambda df, row: df[(df.genero == row.genero) & (df.epiteto == row.epiteto)
                       & (df.clave_ecoregion_n2 == row.clave_ecoregion_n2) & (df.clave_bur == row.clave_bur)
                       & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],

    # Especie + ecoregión + rango diamétrico
    lambda df, row: df[(df.genero == row.genero) & (df.epiteto == row.epiteto)
                       & (df.clave_ecoregion_n2 == row.clave_ecoregion_n2)
                       & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],

    # Especie + clave BUR + rango diamétrico
    lambda df, row: df[(df.genero == row.genero) & (df.epiteto == row.epiteto)
                       & (df.clave_bur == row.clave_bur)
                       & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],

    # Especie + rango diamétrico
    lambda df, row: df[(df.genero == row.genero) & (df.epiteto == row.epiteto)
                       & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],

    # Género + ecoregión + clave BUR + rango diamétrico
    lambda df, row: df[(df.genero == row.genero) & (df.epiteto.isnull())
                       & (df.clave_ecoregion_n2 == row.clave_ecoregion_n2) & (df.clave_bur == row.clave_bur)
                       & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],

    # Género + ecoregión + rango diamétrico
    lambda df, row: df[(df.genero == row.genero) & (df.epiteto.isnull())
                       & (df.clave_ecoregion_n2 == row.clave_ecoregion_n2)
                       & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],

    # Género + clave BUR + rango diamétrico
    lambda df, row: df[(df.genero == row.genero) & (df.epiteto.isnull())
                       & (df.clave_bur == row.clave_bur)
                       & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],

    # Género + rango diamétrico
    lambda df, row: df[(df.genero == row.genero) & (df.epiteto.isnull())
                       & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],

    # Afinidad de género + ecoregión + clave BUR + rango diamétrico
    lambda df, row: df[(df.genero == row.genero) 
                       & (df.clave_ecoregion_n2 == row.clave_ecoregion_n2) & (df.clave_bur == row.clave_bur)
                       & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],

    # Afinidad de género + ecoregión + rango diamétrico
    lambda df, row: df[(df.genero == row.genero) 
                       & (df.clave_ecoregion_n2 == row.clave_ecoregion_n2)
                       & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],

    # Afinidad de género + clave BUR + rango diamétrico
    lambda df, row: df[(df.genero == row.genero) 
                       & (df.clave_bur == row.clave_bur)
                       & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],

    # Afinidad de género + rango diamétrico
    lambda df, row: df[(df.genero == row.genero) 
                       & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],

    # Ecoregión + clave BUR + rango diamétrico
    lambda df, row: df[(df.clave_ecoregion_n2 == row.clave_ecoregion_n2) & (df.clave_bur == row.clave_bur)
                       & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],

    # Ecoregión + rango diamétrico
    lambda df, row: df[(df.clave_ecoregion_n2 == row.clave_ecoregion_n2)
                       & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],

    # Clave BUR + rango diamétrico
    lambda df, row: df[(df.clave_bur == row.clave_bur)
                       & (df.diametro_min <= row.diametro) & (df.diametro_max >= row.diametro)],

    # General para volumen tocones
    lambda df, row: df[(df.id == 2885) & (row.condicion == "Tocón")],

    # General para volumen muertos en pie
    lambda df, row: df[(df.id == 2884) & (row.id == "Muerto")]
]

# %%
equations = modelos[(modelos.variable_resultado == "v") & (modelos.activo ==1)]

# %%
equations
# Out:
#         id  id_anterior variable_resultado     tipo  \
# 2883  2884       2868.0                  v  General
# 2884  2885       2869.0                  v  General
#
#                                          ecuacion  \
# 2883  (3.14159 * ((d130 / 2 / 100) ^ 2) * ht) / 3
# 2884      (3.14159 * ((d130 / 2 / 100) ^ 2) * ht)
#
#                                           ecuacion_php  especie_id familia  \
# 2883  (3.14159 * (([d130] / 2 / 100) ** 2) * [ht]) / 3         NaN     NaN
# 2884      (3.14159 * (([d130] / 2 / 100) ** 2) * [ht])         NaN     NaN
#
#      genero epiteto condicion     componente  diametro_min  diametro_max  \
# 2883    NaN     NaN    Muerto  Todo el árbol           NaN           NaN
# 2884    NaN     NaN     Tocón  Todo el árbol           NaN           NaN
#
#       numero_arboles  r2  anio_publicacion  grado_putrefaccion  \
# 2883             NaN NaN               NaN                 NaN
# 2884             NaN NaN               NaN                 NaN
#
#       clave_ecoregion_n1  clave_ecoregion_n2 clave_ecoregion_n3  \
# 2883                 NaN                 NaN                NaN
# 2884                 NaN                 NaN                NaN
#
#      clave_ecoregion_n4 clave_bur  clave_estado_inegi  activo  id_especie_mn  \
# 2883                NaN       NaN                 NaN       1            NaN
# 2884                NaN       NaN                 NaN       1            NaN
#
#       id_modelo_mn referencia  id_referencia  \
# 2883           NaN        NaN            NaN
# 2884           NaN        NaN            NaN
#
#                                                   notas
# 2883  Ecuacion provicional, volumen de un cono en me...
# 2884  Ecuacion provicional, volumen de un cilindro e...

# %%
v_eq = np.empty(n, dtype=object)

# %%
for index, row in df.iterrows():
    for eq  in conditions_eq_3:
        equation_df = eq(equations, row)    
        if not equation_df.empty:
            v_eq[index] = equation_df.iloc[0,5]
            break

# %%
v_eq
# Out:
# array([None, None, None, ..., None, None, None], dtype=object)

# %%
for index, row in df_muerto.iterrows():
    v_eq[index] = modelos.iloc[2883,5]

# %%
for index, row in df_tocon.iterrows():
    if not np.isnan(row.grado_putrefaccion):
        eq = modelos.iloc[2884,5]
        eq+= f"/{row.grado_putrefaccion}"
        print(eq, index)
        v_eq[index] = eq 
        break
    else:
        v_eq[index] = modelos.iloc[2884,5]
# Out:
# (3.14159 * (([d130] / 2 / 100) ** 2) * [ht])/2.0 116

# %%
v_eq[116]
# Out:
# '(3.14159 * (([d130] / 2 / 100) ** 2) * [ht])'

# %%
modelos.iloc[2884,5]
# Out:
# '(3.14159 * (([d130] / 2 / 100) ** 2) * [ht])'

# %%
df_tocon
# Out:
#              id  anio_levantamiento  conglomerado  sitio condicion  \
# 116     2886290                2019         75163      4     Tocón
# 130     2886304                2016         50545      1     Tocón
# 131     2886305                2016         50545      1     Tocón
# 225     2886399                2016         50078      1     Tocón
# 226     2886400                2016         50078      1     Tocón
# ...         ...                 ...           ...    ...       ...
# 830448  3717203                2015         50197      2     Tocón
# 830530  3717285                2016         75151      3     Tocón
# 830538  3717293                2019         49821      4     Tocón
# 830595  3717350                2016         50148      2     Tocón
# 830628  3717383                2017         50179      1     Tocón
#
#         especie_id                 familia                 genero  \
# 116            NaN  ZZ Familia Desconocida  ZZ Genero Desconocido
# 130            NaN                Fagaceae                Quercus
# 131            NaN                Fagaceae                Quercus
# 225            NaN  ZZ Familia Desconocida  ZZ Genero Desconocido
# 226            NaN  ZZ Familia Desconocida  ZZ Genero Desconocido
# ...            ...                     ...                    ...
# 830448         NaN                Fagaceae                Quercus
# 830530         NaN  ZZ Familia Desconocida  ZZ Genero Desconocido
# 830538         NaN  ZZ Familia Desconocida  ZZ Genero Desconocido
# 830595         NaN  ZZ Familia Desconocida  ZZ Genero Desconocido
# 830628         NaN  ZZ Familia Desconocida  ZZ Genero Desconocido
#
#               epiteto categoria_infra infraespecie  numero_arbol  \
# 116               NaN             NaN          NaN             3
# 130     magnoliifolia             NaN          NaN            10
# 131     magnoliifolia             NaN          NaN            13
# 225               NaN             NaN          NaN             1
# 226               NaN             NaN          NaN             5
# ...               ...             ...          ...           ...
# 830448         rugosa             NaN          NaN             2
# 830530            NaN             NaN          NaN             7
# 830538            NaN             NaN          NaN            26
# 830595            NaN             NaN          NaN             3
# 830628            NaN             NaN          NaN            23
#
#         numero_tallo  tallos  diametro  altura  is_predicted    latitud  \
# 116              3.0     NaN      13.0    0.40           0.0  16.658000
# 130             10.0     NaN      36.5    0.30           0.0  21.302167
# 131             13.0     NaN      13.2    0.31           0.0  21.302167
# 225              1.0     NaN      13.8    0.30           0.0  21.387500
# 226              5.0     NaN      11.8    0.30           0.0  21.387500
# ...              ...     ...       ...     ...           ...        ...
# 830448           2.0     NaN      12.5    0.50           0.0  21.394111
# 830530           7.0     NaN      39.1    0.30           0.0  16.677333
# 830538          26.0     NaN      25.5    0.40           0.0  20.866306
# 830595          12.0     NaN      22.7    0.40           0.0  21.417778
# 830628          24.0     NaN      54.3    0.37           0.0  21.406944
#
#           longitud  clave_ecoregion_n2 clave_bur  referencia_1  referencia_2  \
# 116     -96.623583                14.4        BQ        857537             3
# 130    -104.766583                13.4       BQP        475352            10
# 131    -104.766583                13.4       BQP        475355            13
# 225    -105.058917                15.5       SMQ        521110             1
# 226    -105.058917                15.5       SMQ        521114             5
# ...            ...                 ...       ...           ...           ...
# 830448  -99.293306                13.3        BQ        246211             2
# 830530  -97.184944                13.5        BP        523384             7
# 830538  -87.989278                15.2       SMS        859238            26
# 830595 -101.667278                12.2       BQP        521231            12
# 830628 -100.165333                13.3       BQP        654372            24
#
#         user_id  created_at  updated_at  grado_putrefaccion  \
# 116         NaN         NaN         NaN                 2.0
# 130         NaN         NaN         NaN                 3.0
# 131         NaN         NaN         NaN                 3.0
# 225         NaN         NaN         NaN                 2.0
# 226         NaN         NaN         NaN                 2.0
# ...         ...         ...         ...                 ...
# 830448      NaN         NaN         NaN                 NaN
# 830530      NaN         NaN         NaN                 4.0
# 830538      NaN         NaN         NaN                 4.0
# 830595      NaN         NaN         NaN                 3.0
# 830628      NaN         NaN         NaN                 3.0
#
#         clave_ecoregion_n1 clave_ecoregion_n3 clave_ecoregion_n4  \
# 116                     14             14.4.3           14.4.3.3
# 130                     13             13.4.2           13.4.2.2
# 131                     13             13.4.2           13.4.2.2
# 225                     15             15.5.2           15.5.2.2
# 226                     15             15.5.2           15.5.2.2
# ...                    ...                ...                ...
# 830448                  13             13.3.1           13.3.1.1
# 830530                  13             13.5.2           13.5.2.1
# 830538                  15             15.2.1           15.2.1.1
# 830595                  12             12.2.1           12.2.1.2
# 830628                  13             13.3.1           13.3.1.1
#
#         estado_inegi      estado  edad
# 116               20      Oaxaca   NaN
# 130               18     Nayarit   NaN
# 131               18     Nayarit   NaN
# 225               18     Nayarit   NaN
# 226               18     Nayarit   NaN
# ...              ...         ...   ...
# 830448            22   Querétaro   NaN
# 830530            20      Oaxaca   NaN
# 830538            31     Yucatán   NaN
# 830595            14     Jalisco   NaN
# 830628            11  Guanajuato   NaN
#
# [14251 rows x 33 columns]

# %%
row = df_tocon.loc[830448]
if np.isnan(row.grado_putrefaccion):
    print(1)# == np.nan
# Out:
# 1

# %%
np.save('v_eq.npy', v_eq)

# %%
df_tocon.grado_putrefaccion.value_counts()
# Out:
# grado_putrefaccion
# 3.0    5829
# 2.0    3515
# 4.0    1104
# 1.0     590
# 5.0      24
# Name: count, dtype: int64

# %%
df.to_csv("out_fixed_v2_2.csv", index=False)

# %%
len(df)
# Out:
# 830750
