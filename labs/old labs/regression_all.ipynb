# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
import math 
from sklearn.linear_model import LinearRegression # type: ignore
import joblib

# %%
pd.set_option('display.max_columns', None)

# %%
arboles = f'../csvs/arboles.csv'

# %%
df = pd.read_csv(arboles)
# Out:
# /tmp/ipykernel_25017/3508885309.py:1: DtypeWarning: Columns (9,10,20,23,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(arboles)

# %% [markdown]
# # diametro

# %%
df_species = df
X_train  = ["diametro"]
y_train = "altura"

# %%
train_df_ = df_species[(df_species[y_train].notnull())]
train_df = train_df_[( train_df_[X_train[0]].notnull())]

# %%
train_df
# Out:
#               id  anio_levantamiento  conglomerado  sitio condicion  \
# 0              1                2005            60      1      Vivo
# 1              2                2005            64      4      Vivo
# 2              3                2005           153      1      Vivo
# 3              4                2005           153      1      Vivo
# 4              5                2005           153      1      Vivo
# ...          ...                 ...           ...    ...       ...
# 3717474  3717500                2016         50303      1      Vivo
# 3717475  3717501                2016         50303      2      Vivo
# 3717476  3717502                2016         50303      2      Vivo
# 3717477  3717503                2016         50303      2      Vivo
# 3717478  3717504                2016         50303      2      Vivo
#
#          especie_id        familia          genero      epiteto  \
# 0             680.0      Ericaceae  Arctostaphylos          NaN
# 1           26426.0       Pinaceae           Pinus  quadrifolia
# 2           26426.0       Pinaceae           Pinus  quadrifolia
# 3           26426.0       Pinaceae           Pinus  quadrifolia
# 4           26426.0       Pinaceae           Pinus  quadrifolia
# ...             ...            ...             ...          ...
# 3717474         NaN       Fabaceae     Caesalpinia    platyloba
# 3717475         NaN       Fabaceae        Swartzia     cubensis
# 3717476         NaN      Arecaceae           Sabal         yapa
# 3717477         NaN     Sapotaceae       Manilkara       zapota
# 3717478         NaN  Anacardiaceae        Metopium      brownei
#
#         categoria_infra infraespecie  numero_arbol  numero_tallo  tallos  \
# 0                   NaN          NaN             1           NaN     3.0
# 1                   NaN          NaN             1           NaN     0.0
# 2                   NaN          NaN             1           NaN     NaN
# 3                   NaN          NaN             2           NaN     NaN
# 4                   NaN          NaN             3           NaN     NaN
# ...                 ...          ...           ...           ...     ...
# 3717474             NaN          NaN             6           6.0     NaN
# 3717475             NaN          NaN            12          13.0     NaN
# 3717476             NaN          NaN            13          14.0     NaN
# 3717477             NaN          NaN            24          25.0     NaN
# 3717478             NaN          NaN             9          10.0     NaN
#
#          diametro  altura    latitud    longitud  clave_ecoregion_n2  \
# 0             8.3    3.20  32.515597 -116.350450                11.1
# 1            14.0    5.50  32.532903 -116.140585                11.1
# 2            17.0    5.50  32.448351 -116.077138                11.1
# 3            14.5    5.85  32.448351 -116.077138                11.1
# 4            21.0    6.25  32.448351 -116.077138                11.1
# ...           ...     ...        ...         ...                 ...
# 3717474      17.8    9.10  20.693639  -87.135167                15.2
# 3717475       8.3    7.80  20.693639  -87.135167                15.2
# 3717476      17.7   10.30  20.693639  -87.135167                15.2
# 3717477      32.3    9.10  20.693639  -87.135167                15.2
# 3717478       8.4    7.70  20.693639  -87.135167                15.2
#
#         clave_bur                     referencia_1  referencia_2  user_id  \
# 0             MXL  caracteristica_vegetacion_mayor        107497      1.0
# 1             MXL  caracteristica_vegetacion_mayor        101063      1.0
# 2             BCO          caracteristica_arbolado             1      1.0
# 3             BCO          caracteristica_arbolado             2      1.0
# 4             BCO          caracteristica_arbolado             3      1.0
# ...           ...                              ...           ...      ...
# 3717474       SMQ                           523099             6      NaN
# 3717475       SMQ                           523135            13      NaN
# 3717476       SMQ                           523136            14      NaN
# 3717477       SMQ                           523147            25      NaN
# 3717478       SMQ                           523132            10      NaN
#
#                       created_at               updated_at  grado_putrefaccion  \
# 0        2019-11-14 20:24:49.070  2019-11-14 20:24:49.070                 NaN
# 1        2019-11-14 20:24:49.070  2019-11-14 20:24:49.070                 NaN
# 2        2019-11-14 20:24:49.070  2019-11-14 20:24:49.070                 NaN
# 3        2019-11-14 20:24:49.070  2019-11-14 20:24:49.070                 NaN
# 4        2019-11-14 20:24:49.070  2019-11-14 20:24:49.070                 NaN
# ...                          ...                      ...                 ...
# 3717474                      NaN                      NaN                 NaN
# 3717475                      NaN                      NaN                 NaN
# 3717476                      NaN                      NaN                 NaN
# 3717477                      NaN                      NaN                 NaN
# 3717478                      NaN                      NaN                 NaN
#
#          clave_ecoregion_n1 clave_ecoregion_n3 clave_ecoregion_n4  \
# 0                        11             11.1.1           11.1.1.3
# 1                        11             11.1.1           11.1.1.3
# 2                        11             11.1.3           11.1.3.1
# 3                        11             11.1.3           11.1.3.1
# 4                        11             11.1.3           11.1.3.1
# ...                     ...                ...                ...
# 3717474                  15             15.2.2           15.2.2.2
# 3717475                  15             15.2.2           15.2.2.2
# 3717476                  15             15.2.2           15.2.2.2
# 3717477                  15             15.2.2           15.2.2.2
# 3717478                  15             15.2.2           15.2.2.2
#
#          estado_inegi           estado  edad
# 0                   2  Baja California   NaN
# 1                   2  Baja California   NaN
# 2                   2  Baja California  74.0
# 3                   2  Baja California  61.0
# 4                   2  Baja California   NaN
# ...               ...              ...   ...
# 3717474            23     Quintana Roo   NaN
# 3717475            23     Quintana Roo   NaN
# 3717476            23     Quintana Roo   NaN
# 3717477            23     Quintana Roo   NaN
# 3717478            23     Quintana Roo   NaN
#
# [3700680 rows x 32 columns]

# %%
X_train_df = train_df[X_train]
y_train_df = train_df[[y_train]]

# %%
y_train_df
# Out:
#          altura
# 0          3.20
# 1          5.50
# 2          5.50
# 3          5.85
# 4          6.25
# ...         ...
# 3717474    9.10
# 3717475    7.80
# 3717476   10.30
# 3717477    9.10
# 3717478    7.70
#
# [3700680 rows x 1 columns]

# %%
X_train_df
# Out:
#          diametro
# 0             8.3
# 1            14.0
# 2            17.0
# 3            14.5
# 4            21.0
# ...           ...
# 3717474      17.8
# 3717475       8.3
# 3717476      17.7
# 3717477      32.3
# 3717478       8.4
#
# [3700680 rows x 1 columns]

# %%
y_train_df
# Out:
#          altura
# 0          3.20
# 1          5.50
# 2          5.50
# 3          5.85
# 4          6.25
# ...         ...
# 3717474    9.10
# 3717475    7.80
# 3717476   10.30
# 3717477    9.10
# 3717478    7.70
#
# [3700680 rows x 1 columns]

# %%
model = LinearRegression()
model.fit(X_train_df, y_train_df)
# Out:
# LinearRegression()

# %%
predict_df = df_species[df_species[y_train].isnull()]

# %%
X_predict = predict_df[X_train]

# %%
X_predict.isnull()
# Out:
#          diametro
# 1312404     False
# 1547105     False
# 1667931      True
# 2689130     False
# 2887703     False
# ...           ...
# 3716931     False
# 3716933     False
# 3716934     False
# 3717282     False
# 3717283     False
#
# [2301 rows x 1 columns]

# %%
X_predict
df_clean = X_predict.dropna()
df_clean
# Out:
#          diametro
# 1312404       9.9
# 1547105      10.1
# 2689130      13.8
# 2887703      12.9
# 2887742      16.5
# ...           ...
# 3716931      17.0
# 3716933      14.8
# 3716934      19.3
# 3717282      16.5
# 3717283      18.3
#
# [2186 rows x 1 columns]

# %%
joblib.dump(model, 'linear_regression_diametro.pkl')
# Out:
# ['linear_regression_diametro.pkl']

# %% [markdown]
# # altura

# %%
df_species = df
X_train  = ["altura"]
y_train = "diametro"

# %%
train_df_ = df_species[(df_species[y_train].notnull())]
train_df = train_df_[( train_df_[X_train[0]].notnull())]

# %%
train_df
# Out:
#               id  anio_levantamiento  conglomerado  sitio condicion  \
# 0              1                2005            60      1      Vivo
# 1              2                2005            64      4      Vivo
# 2              3                2005           153      1      Vivo
# 3              4                2005           153      1      Vivo
# 4              5                2005           153      1      Vivo
# ...          ...                 ...           ...    ...       ...
# 3717474  3717500                2016         50303      1      Vivo
# 3717475  3717501                2016         50303      2      Vivo
# 3717476  3717502                2016         50303      2      Vivo
# 3717477  3717503                2016         50303      2      Vivo
# 3717478  3717504                2016         50303      2      Vivo
#
#          especie_id        familia          genero      epiteto  \
# 0             680.0      Ericaceae  Arctostaphylos          NaN
# 1           26426.0       Pinaceae           Pinus  quadrifolia
# 2           26426.0       Pinaceae           Pinus  quadrifolia
# 3           26426.0       Pinaceae           Pinus  quadrifolia
# 4           26426.0       Pinaceae           Pinus  quadrifolia
# ...             ...            ...             ...          ...
# 3717474         NaN       Fabaceae     Caesalpinia    platyloba
# 3717475         NaN       Fabaceae        Swartzia     cubensis
# 3717476         NaN      Arecaceae           Sabal         yapa
# 3717477         NaN     Sapotaceae       Manilkara       zapota
# 3717478         NaN  Anacardiaceae        Metopium      brownei
#
#         categoria_infra infraespecie  numero_arbol  numero_tallo  tallos  \
# 0                   NaN          NaN             1           NaN     3.0
# 1                   NaN          NaN             1           NaN     0.0
# 2                   NaN          NaN             1           NaN     NaN
# 3                   NaN          NaN             2           NaN     NaN
# 4                   NaN          NaN             3           NaN     NaN
# ...                 ...          ...           ...           ...     ...
# 3717474             NaN          NaN             6           6.0     NaN
# 3717475             NaN          NaN            12          13.0     NaN
# 3717476             NaN          NaN            13          14.0     NaN
# 3717477             NaN          NaN            24          25.0     NaN
# 3717478             NaN          NaN             9          10.0     NaN
#
#          diametro  altura    latitud    longitud  clave_ecoregion_n2  \
# 0             8.3    3.20  32.515597 -116.350450                11.1
# 1            14.0    5.50  32.532903 -116.140585                11.1
# 2            17.0    5.50  32.448351 -116.077138                11.1
# 3            14.5    5.85  32.448351 -116.077138                11.1
# 4            21.0    6.25  32.448351 -116.077138                11.1
# ...           ...     ...        ...         ...                 ...
# 3717474      17.8    9.10  20.693639  -87.135167                15.2
# 3717475       8.3    7.80  20.693639  -87.135167                15.2
# 3717476      17.7   10.30  20.693639  -87.135167                15.2
# 3717477      32.3    9.10  20.693639  -87.135167                15.2
# 3717478       8.4    7.70  20.693639  -87.135167                15.2
#
#         clave_bur                     referencia_1  referencia_2  user_id  \
# 0             MXL  caracteristica_vegetacion_mayor        107497      1.0
# 1             MXL  caracteristica_vegetacion_mayor        101063      1.0
# 2             BCO          caracteristica_arbolado             1      1.0
# 3             BCO          caracteristica_arbolado             2      1.0
# 4             BCO          caracteristica_arbolado             3      1.0
# ...           ...                              ...           ...      ...
# 3717474       SMQ                           523099             6      NaN
# 3717475       SMQ                           523135            13      NaN
# 3717476       SMQ                           523136            14      NaN
# 3717477       SMQ                           523147            25      NaN
# 3717478       SMQ                           523132            10      NaN
#
#                       created_at               updated_at  grado_putrefaccion  \
# 0        2019-11-14 20:24:49.070  2019-11-14 20:24:49.070                 NaN
# 1        2019-11-14 20:24:49.070  2019-11-14 20:24:49.070                 NaN
# 2        2019-11-14 20:24:49.070  2019-11-14 20:24:49.070                 NaN
# 3        2019-11-14 20:24:49.070  2019-11-14 20:24:49.070                 NaN
# 4        2019-11-14 20:24:49.070  2019-11-14 20:24:49.070                 NaN
# ...                          ...                      ...                 ...
# 3717474                      NaN                      NaN                 NaN
# 3717475                      NaN                      NaN                 NaN
# 3717476                      NaN                      NaN                 NaN
# 3717477                      NaN                      NaN                 NaN
# 3717478                      NaN                      NaN                 NaN
#
#          clave_ecoregion_n1 clave_ecoregion_n3 clave_ecoregion_n4  \
# 0                        11             11.1.1           11.1.1.3
# 1                        11             11.1.1           11.1.1.3
# 2                        11             11.1.3           11.1.3.1
# 3                        11             11.1.3           11.1.3.1
# 4                        11             11.1.3           11.1.3.1
# ...                     ...                ...                ...
# 3717474                  15             15.2.2           15.2.2.2
# 3717475                  15             15.2.2           15.2.2.2
# 3717476                  15             15.2.2           15.2.2.2
# 3717477                  15             15.2.2           15.2.2.2
# 3717478                  15             15.2.2           15.2.2.2
#
#          estado_inegi           estado  edad
# 0                   2  Baja California   NaN
# 1                   2  Baja California   NaN
# 2                   2  Baja California  74.0
# 3                   2  Baja California  61.0
# 4                   2  Baja California   NaN
# ...               ...              ...   ...
# 3717474            23     Quintana Roo   NaN
# 3717475            23     Quintana Roo   NaN
# 3717476            23     Quintana Roo   NaN
# 3717477            23     Quintana Roo   NaN
# 3717478            23     Quintana Roo   NaN
#
# [3700680 rows x 32 columns]

# %%
X_train_df = train_df[X_train]
y_train_df = train_df[[y_train]]

# %%
y_train_df
# Out:
#          diametro
# 0             8.3
# 1            14.0
# 2            17.0
# 3            14.5
# 4            21.0
# ...           ...
# 3717474      17.8
# 3717475       8.3
# 3717476      17.7
# 3717477      32.3
# 3717478       8.4
#
# [3700680 rows x 1 columns]

# %%
model = LinearRegression()
model.fit(X_train_df, y_train_df)
# Out:
# LinearRegression()

# %%
predict_df = df_species[df_species[y_train].isnull()]

# %%
X_predict = predict_df[X_train]

# %%
X_predict
df_clean = X_predict.dropna()
df_clean
# Out:
#          altura
# 1508941   999.0
# 2886186    10.6
# 2886224     6.3
# 2886268    28.4
# 2886298     6.5
# ...         ...
# 3716794     9.0
# 3716865     3.8
# 3716972     7.7
# 3717093     5.4
# 3717415     6.3
#
# [14498 rows x 1 columns]

# %%
df.loc[1508941]
# Out:
# id                                            1508966
# anio_levantamiento                               2014
# conglomerado                                    22732
# sitio                                               4
# condicion                                      Muerto
# especie_id                                    31194.0
# familia                                     Cactaceae
# genero                                    Stenocereus
# epiteto                                      thurberi
# categoria_infra                                   NaN
# infraespecie                                      NaN
# numero_arbol                                        8
# numero_tallo                                      8.0
# tallos                                            NaN
# diametro                                          NaN
# altura                                          999.0
# latitud                                     26.830166
# longitud                                   -112.56961
# clave_ecoregion_n2                               10.2
# clave_bur                                         MXL
# referencia_1          caracteristica_vegetacion_mayor
# referencia_2                                   191711
# user_id                                           1.0
# created_at                    2019-11-14 20:24:49.070
# updated_at                    2019-11-14 20:24:49.070
# grado_putrefaccion                                NaN
# clave_ecoregion_n1                                 10
# clave_ecoregion_n3                             10.2.3
# clave_ecoregion_n4                           10.2.3.5
# estado_inegi                                        3
# estado                            Baja California Sur
# edad                                              NaN
# Name: 1508941, dtype: object

# %%
y_predict = model.predict(df_clean)

# %%
y_predict
# Out:
# array([[162.19788583],
#        [ 17.61718653],
#        [ 16.9881932 ],
#        ...,
#        [ 17.19298172],
#        [ 16.85654343],
#        [ 16.9881932 ]])

# %%
joblib.dump(model, 'linear_regression_altura.pkl')
# Out:
# ['linear_regression_altura.pkl']
