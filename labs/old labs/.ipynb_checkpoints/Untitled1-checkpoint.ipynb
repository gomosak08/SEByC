# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
import math

# %%
df = pd.read_csv("../out.csv")

# %%
df
# Out:
#             id  anio_levantamiento  conglomerado  sitio condicion  especie_id  \
# 0            1                2005            60      1      Vivo       680.0
# 1            2                2005            64      4      Vivo     26426.0
# 2            3                2005           153      1      Vivo     26426.0
# 3            4                2005           153      1      Vivo     26426.0
# 4            5                2005           153      1      Vivo     26426.0
# ...        ...                 ...           ...    ...       ...         ...
# 99996    99997                2005         14554      2      Vivo     16165.0
# 99997    99998                2005         14554      2      Vivo     16165.0
# 99998    99999                2005         14554      2      Vivo     16165.0
# 99999   100000                2005         14554      2      Vivo     32764.0
# 100000  100001                2005         14554      2    Muerto     33449.0
#
# ...
