# %%
import pandas as pd
import numpy as np
import re

# %%
import sys
from pathlib import Path

# Add the parent directory to sys.path
sys.path.append(str(Path().resolve().parent))

# Now import the module
from normalization.conditions import assign_equations, volumen

# %%
pd.set_option('display.max_columns', None)

# %%
df_original = pd.read_csv('../csvs/ciclo_1.csv', low_memory=False)
modelos = pd.read_excel('../csvs/modelos.xlsx')
df_regression = pd.read_csv('../linear_regression/ciclo1_out.csv',low_memory=False)
print("All the files where opened correctly")
# Out:
# All the files where opened correctly

# %%
n = len(df_original)
is_predicted = np.zeros(n)
df_original.insert(16, 'is_predicted', is_predicted)
print("Insertion correctly")
# Out:
# Insertion correctly

# %%
index = df_regression.index
df_original.loc[index] = df_regression
print("The original was changed for regression data")
# Out:
# The original was changed for regression data

# %%
df_original.loc[(df_original.condicion == "Tocón") & (df_original.altura <= 0) , "altura"] = .3
df_original.loc[(df_original.condicion == "Tocón") & (df_original.altura.isnull()), "altura"] = .3

df_original.loc[(df_original.condicion == "Tocón") & (df_original.diametro <= 0), "diametro"] = 7.5
df_original.loc[(df_original.condicion == "Tocón") & (df_original.diametro.isnull()), "diametro"] = .3


df_original.loc[(df_original.condicion != "Tocón") & (df_original.diametro.isnull()), "diametro"] = 7.5
df_original.loc[(df_original.condicion != "Tocón") & (df_original.altura.isnull()), "altura"] = 1.3

#b_eq = np.empty(n, dtype=object)

# %%
df_original
# Out:
#               id  anio_levantamiento  conglomerado  sitio condicion  \
# 0              1                2005            60      1      Vivo
# 1              2                2005            64      4      Vivo
# 2              3                2005           153      1      Vivo
# 3              4                2005           153      1      Vivo
# 4              5                2005           153      1      Vivo
# ...          ...                 ...           ...    ...       ...
# 1305125  1305126                2005         78002      4      Vivo
# 1305126  1305127                2005         78002      4      Vivo
# 1305127  1305128                2005         78002      4      Vivo
# 1305128  1305129                2005         78002      4      Vivo
# 1305129  1305130                2005         78002      4      Vivo
#
#          especie_id         familia          genero      epiteto  \
# 0             680.0       Ericaceae  Arctostaphylos          NaN
# 1           26426.0        Pinaceae           Pinus  quadrifolia
# 2           26426.0        Pinaceae           Pinus  quadrifolia
# 3           26426.0        Pinaceae           Pinus  quadrifolia
# 4           26426.0        Pinaceae           Pinus  quadrifolia
# ...             ...             ...             ...          ...
# 1305125     19494.0  Rhizophoraceae      Rhizophora       mangle
# 1305126     19494.0  Rhizophoraceae      Rhizophora       mangle
# 1305127     19494.0  Rhizophoraceae      Rhizophora       mangle
# 1305128     19494.0  Rhizophoraceae      Rhizophora       mangle
# 1305129     19494.0  Rhizophoraceae      Rhizophora       mangle
#
#         categoria_infra infraespecie  numero_arbol  numero_tallo  tallos  \
# 0                   NaN          NaN             1           NaN     3.0
# 1                   NaN          NaN             1           NaN     0.0
# 2                   NaN          NaN             1           NaN     NaN
# 3                   NaN          NaN             2           NaN     NaN
# 4                   NaN          NaN             3           NaN     NaN
# ...                 ...          ...           ...           ...     ...
# 1305125             NaN          NaN             6           NaN     NaN
# 1305126             NaN          NaN             7           NaN     NaN
# 1305127             NaN          NaN             8           NaN     NaN
# 1305128             NaN          NaN             9           NaN     NaN
# 1305129             NaN          NaN            10           NaN     NaN
#
#          diametro  altura  is_predicted    latitud    longitud  \
# 0             8.3    3.20           0.0  32.515597 -116.350450
# 1            14.0    5.50           0.0  32.532903 -116.140585
# 2            17.0    5.50           0.0  32.448351 -116.077138
# 3            14.5    5.85           0.0  32.448351 -116.077138
# 4            21.0    6.25           0.0  32.448351 -116.077138
# ...           ...     ...           ...        ...         ...
# 1305125      31.5   20.00           0.0  14.587356  -92.270686
# 1305126      35.3   20.00           0.0  14.587356  -92.270686
# 1305127      30.0   19.00           0.0  14.587356  -92.270686
# 1305128      30.0   20.00           0.0  14.587356  -92.270686
# 1305129      48.0   22.00           0.0  14.587356  -92.270686
#
#          clave_ecoregion_n2 clave_bur                     referencia_1  \
# 0                      11.1       MXL  caracteristica_vegetacion_mayor
# 1                      11.1       MXL  caracteristica_vegetacion_mayor
# 2                      11.1       BCO          caracteristica_arbolado
# 3                      11.1       BCO          caracteristica_arbolado
# 4                      11.1       BCO          caracteristica_arbolado
# ...                     ...       ...                              ...
# 1305125                15.6       VHL          caracteristica_arbolado
# 1305126                15.6       VHL          caracteristica_arbolado
# 1305127                15.6       VHL          caracteristica_arbolado
# 1305128                15.6       VHL          caracteristica_arbolado
# 1305129                15.6       VHL          caracteristica_arbolado
#
#          referencia_2  user_id               created_at  \
# 0              107497      1.0  2019-11-14 20:24:49.070
# 1              101063      1.0  2019-11-14 20:24:49.070
# 2                   1      1.0  2019-11-14 20:24:49.070
# 3                   2      1.0  2019-11-14 20:24:49.070
# 4                   3      1.0  2019-11-14 20:24:49.070
# ...               ...      ...                      ...
# 1305125       1267537      1.0  2019-11-14 20:24:49.070
# 1305126       1267536      1.0  2019-11-14 20:24:49.070
# 1305127       1267535      1.0  2019-11-14 20:24:49.070
# 1305128       1267533      1.0  2019-11-14 20:24:49.070
# 1305129       1267534      1.0  2019-11-14 20:24:49.070
#
#                       updated_at  grado_putrefaccion  clave_ecoregion_n1  \
# 0        2019-11-14 20:24:49.070                 NaN                  11
# 1        2019-11-14 20:24:49.070                 NaN                  11
# 2        2019-11-14 20:24:49.070                 NaN                  11
# 3        2019-11-14 20:24:49.070                 NaN                  11
# 4        2019-11-14 20:24:49.070                 NaN                  11
# ...                          ...                 ...                 ...
# 1305125  2019-11-14 20:24:49.070                 NaN                  15
# 1305126  2019-11-14 20:24:49.070                 NaN                  15
# 1305127  2019-11-14 20:24:49.070                 NaN                  15
# 1305128  2019-11-14 20:24:49.070                 NaN                  15
# 1305129  2019-11-14 20:24:49.070                 NaN                  15
#
#         clave_ecoregion_n3 clave_ecoregion_n4  estado_inegi           estado  \
# 0                   11.1.1           11.1.1.3             2  Baja California
# 1                   11.1.1           11.1.1.3             2  Baja California
# 2                   11.1.3           11.1.3.1             2  Baja California
# 3                   11.1.3           11.1.3.1             2  Baja California
# 4                   11.1.3           11.1.3.1             2  Baja California
# ...                    ...                ...           ...              ...
# 1305125             15.6.1           15.6.1.1             7          Chiapas
# 1305126             15.6.1           15.6.1.1             7          Chiapas
# 1305127             15.6.1           15.6.1.1             7          Chiapas
# 1305128             15.6.1           15.6.1.1             7          Chiapas
# 1305129             15.6.1           15.6.1.1             7          Chiapas
#
#          edad
# 0         NaN
# 1         NaN
# 2        74.0
# 3        61.0
# 4         NaN
# ...       ...
# 1305125   NaN
# 1305126   NaN
# 1305127   NaN
# 1305128   NaN
# 1305129   NaN
#
# [1305130 rows x 33 columns]

# %%
df_original.iloc[:10]
# Out:
#    id  anio_levantamiento  conglomerado  sitio condicion  especie_id  \
# 0   1                2005            60      1      Vivo       680.0
# 1   2                2005            64      4      Vivo     26426.0
# 2   3                2005           153      1      Vivo     26426.0
# 3   4                2005           153      1      Vivo     26426.0
# 4   5                2005           153      1      Vivo     26426.0
# 5   6                2005           153      1      Vivo      7758.0
# 6   7                2005           153      1      Vivo      2270.0
# 7   8                2005           153      1      Vivo      2270.0
# 8   9                2005           153      1      Vivo      2270.0
# 9  10                2005           153      1      Vivo      2270.0
#
#         familia          genero      epiteto categoria_infra infraespecie  \
# 0     Ericaceae  Arctostaphylos          NaN             NaN          NaN
# 1      Pinaceae           Pinus  quadrifolia             NaN          NaN
# 2      Pinaceae           Pinus  quadrifolia             NaN          NaN
# 3      Pinaceae           Pinus  quadrifolia             NaN          NaN
# 4      Pinaceae           Pinus  quadrifolia             NaN          NaN
# 5  Cupressaceae       Juniperus  californica             NaN          NaN
# 6  Cupressaceae       Juniperus          NaN             NaN          NaN
# 7  Cupressaceae       Juniperus          NaN             NaN          NaN
# 8  Cupressaceae       Juniperus          NaN             NaN          NaN
# 9  Cupressaceae       Juniperus          NaN             NaN          NaN
#
#    numero_arbol  numero_tallo  tallos   diametro  altura  is_predicted  \
# 0             1           NaN     3.0   8.300000    3.20           0.0
# 1             1           NaN     0.0  14.000000    5.50           0.0
# 2             1           NaN     NaN  17.000000    5.50           0.0
# 3             2           NaN     NaN  14.500000    5.85           0.0
# 4             3           NaN     NaN  21.000000    6.25           0.0
# 5             4           NaN     NaN  13.500000    3.20           0.0
# 6             5           NaN     NaN  13.500000    3.00           0.0
# 7             6           NaN     NaN   9.000000    2.90           0.0
# 8             7           NaN     NaN   9.500000    3.00           0.0
# 9             8           NaN     NaN  11.588285    3.50           2.0
#
#      latitud    longitud  clave_ecoregion_n2 clave_bur  \
# 0  32.515597 -116.350450                11.1       MXL
# 1  32.532903 -116.140585                11.1       MXL
# 2  32.448351 -116.077138                11.1       BCO
# 3  32.448351 -116.077138                11.1       BCO
# 4  32.448351 -116.077138                11.1       BCO
# 5  32.448351 -116.077138                11.1       BCO
# 6  32.448351 -116.077138                11.1       BCO
# 7  32.448351 -116.077138                11.1       BCO
# 8  32.448351 -116.077138                11.1       BCO
# 9  32.448351 -116.077138                11.1       BCO
#
#                       referencia_1  referencia_2  user_id  \
# 0  caracteristica_vegetacion_mayor        107497      1.0
# 1  caracteristica_vegetacion_mayor        101063      1.0
# 2          caracteristica_arbolado             1      1.0
# 3          caracteristica_arbolado             2      1.0
# 4          caracteristica_arbolado             3      1.0
# 5          caracteristica_arbolado             4      1.0
# 6          caracteristica_arbolado             5      1.0
# 7          caracteristica_arbolado             6      1.0
# 8          caracteristica_arbolado             7      1.0
# 9          caracteristica_arbolado             8      1.0
#
#                 created_at               updated_at  grado_putrefaccion  \
# 0  2019-11-14 20:24:49.070  2019-11-14 20:24:49.070                 NaN
# 1  2019-11-14 20:24:49.070  2019-11-14 20:24:49.070                 NaN
# 2  2019-11-14 20:24:49.070  2019-11-14 20:24:49.070                 NaN
# 3  2019-11-14 20:24:49.070  2019-11-14 20:24:49.070                 NaN
# 4  2019-11-14 20:24:49.070  2019-11-14 20:24:49.070                 NaN
# 5  2019-11-14 20:24:49.070  2019-11-14 20:24:49.070                 NaN
# 6  2019-11-14 20:24:49.070  2019-11-14 20:24:49.070                 NaN
# 7  2019-11-14 20:24:49.070  2019-11-14 20:24:49.070                 NaN
# 8  2019-11-14 20:24:49.070  2019-11-14 20:24:49.070                 NaN
# 9  2019-11-14 20:24:49.070  2019-11-14 20:24:49.070                 NaN
#
#    clave_ecoregion_n1 clave_ecoregion_n3 clave_ecoregion_n4  estado_inegi  \
# 0                  11             11.1.1           11.1.1.3             2
# 1                  11             11.1.1           11.1.1.3             2
# 2                  11             11.1.3           11.1.3.1             2
# 3                  11             11.1.3           11.1.3.1             2
# 4                  11             11.1.3           11.1.3.1             2
# 5                  11             11.1.3           11.1.3.1             2
# 6                  11             11.1.3           11.1.3.1             2
# 7                  11             11.1.3           11.1.3.1             2
# 8                  11             11.1.3           11.1.3.1             2
# 9                  11             11.1.3           11.1.3.1             2
#
#             estado  edad
# 0  Baja California   NaN
# 1  Baja California   NaN
# 2  Baja California  74.0
# 3  Baja California  61.0
# 4  Baja California   NaN
# 5  Baja California   NaN
# 6  Baja California   NaN
# 7  Baja California   NaN
# 8  Baja California   NaN
# 9  Baja California   NaN

# %%
df_10 = df_original.iloc[:10000]

# %%
b_eq = assign_equations(df_10, modelos, variable_resultado="b", conditions="biomasa")
# Out:
#   1%|▎                                      | 86/10000 [00:00<00:23, 416.59it/s]
# this is working and here is the indices [np.int64(117), np.int64(114), np.int64(114), np.int64(455)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(339), np.int64(339), np.int64(402), np.int64(339)]
# this is working and here is the indices [np.int64(339), np.int64(339), np.int64(402), np.int64(339)]
# this is working and here is the indices [np.int64(339), np.int64(339), np.int64(402), np.int64(339)]
# this is working and here is the indices [np.int64(339), np.int64(339), np.int64(402), np.int64(339)]
# this is working and here is the indices [np.int64(339), np.int64(339), np.int64(402), np.int64(339)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(339), np.int64(339), np.int64(402), np.int64(339)]
# this is working and here is the indices [np.int64(339), np.int64(339), np.int64(402), np.int64(339)]
# this is working and here is the indices [np.int64(339), np.int64(339), np.int64(402), np.int64(339)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(112), np.int64(112), np.int64(112), np.int64(112)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(112), np.int64(112), np.int64(112), np.int64(112)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(112), np.int64(112), np.int64(112), np.int64(112)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(112), np.int64(112), np.int64(112), np.int64(112)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(112), np.int64(112), np.int64(112), np.int64(112)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(112), np.int64(112), np.int64(112), np.int64(112)]
# this is working and here is the indices [np.int64(112), np.int64(112), np.int64(112), np.int64(112)]
# this is working and here is the indices [np.int64(339), np.int64(339), np.int64(402), np.int64(339)]
# this is working and here is the indices [np.int64(339), np.int64(339), np.int64(402), np.int64(339)]
# this is working and here is the indices [np.int64(339), np.int64(339), np.int64(402), np.int64(339)]
# this is working and here is the indices [np.int64(339), np.int64(339), np.int64(402), np.int64(339)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(339), np.int64(339), np.int64(402), np.int64(339)]
# this is working and here is the indices [np.int64(339), np.int64(339), np.int64(402), np.int64(339)]
# this is working and here is the indices [np.int64(339), np.int64(339), np.int64(402), np.int64(339)]
# this is working and here is the indices [np.int64(339), np.int64(339), np.int64(402), np.int64(339)]
# this is working and here is the indices [np.int64(339), np.int64(339), np.int64(402), np.int64(339)]
# this is working and here is the indices [np.int64(339), np.int64(339), np.int64(402), np.int64(339)]
# this is working and here is the indices [np.int64(339), np.int64(339), np.int64(402), np.int64(339)]
# this is working and here is the indices [np.int64(339), np.int64(339), np.int64(402), np.int64(339)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(112), np.int64(112), np.int64(112), np.int64(112)]
# this is working and here is the indices [np.int64(112), np.int64(112), np.int64(112), np.int64(112)]
# this is working and here is the indices [np.int64(112), np.int64(112), np.int64(112), np.int64(112)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(112), np.int64(112), np.int64(112), np.int64(112)]
# this is working and here is the indices [np.int64(112), np.int64(112), np.int64(112), np.int64(112)]
# this is working and here is the indices [np.int64(112), np.int64(112), np.int64(112), np.int64(112)]
# this is working and here is the indices [np.int64(112), np.int64(112), np.int64(112), np.int64(112)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(339), np.int64(339), np.int64(402), np.int64(339)]
# this is working and here is the indices [np.int64(339), np.int64(339), np.int64(402), np.int64(339)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(170), np.int64(170), np.int64(170), np.int64(170)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(170), np.int64(170), np.int64(170), np.int64(170)]
# this is working and here is the indices [np.int64(170), np.int64(170), np.int64(170), np.int64(170)]
# this is working and here is the indices [np.int64(170), np.int64(170), np.int64(170), np.int64(170)]
# this is working and here is the indices [np.int64(170), np.int64(170), np.int64(170), np.int64(170)]
#   2%|▋                                     | 188/10000 [00:00<00:21, 461.49it/s]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(170), np.int64(170), np.int64(170), np.int64(170)]
# this is working and here is the indices [np.int64(170), np.int64(170), np.int64(170), np.int64(170)]
# this is working and here is the indices [np.int64(170), np.int64(170), np.int64(170), np.int64(170)]
# this is working and here is the indices [np.int64(170), np.int64(170), np.int64(170), np.int64(170)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(170), np.int64(170), np.int64(170), np.int64(170)]
# this is working and here is the indices [np.int64(170), np.int64(170), np.int64(170), np.int64(170)]
# this is working and here is the indices [np.int64(170), np.int64(170), np.int64(170), np.int64(170)]
# this is working and here is the indices [np.int64(170), np.int64(170), np.int64(170), np.int64(170)]
# this is working and here is the indices [np.int64(170), np.int64(170), np.int64(170), np.int64(170)]
# this is working and here is the indices [np.int64(170), np.int64(170), np.int64(170), np.int64(170)]
# this is working and here is the indices [np.int64(170), np.int64(170), np.int64(170), np.int64(170)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(170), np.int64(170), np.int64(170), np.int64(170)]
# this is working and here is the indices [np.int64(170), np.int64(170), np.int64(170), np.int64(170)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(117), np.int64(114), np.int64(114), np.int64(455)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(117), np.int64(114), np.int64(114), np.int64(455)]
# this is working and here is the indices [np.int64(112), np.int64(112), np.int64(112), np.int64(112)]
# this is working and here is the indices [np.int64(112), np.int64(112), np.int64(112), np.int64(112)]
# this is working and here is the indices [np.int64(112), np.int64(112), np.int64(112), np.int64(112)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(117), np.int64(114), np.int64(114), np.int64(455)]
# this is working and here is the indices [np.int64(117), np.int64(114), np.int64(114), np.int64(455)]
# this is working and here is the indices [np.int64(112), np.int64(112), np.int64(112), np.int64(112)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(112), np.int64(112), np.int64(112), np.int64(112)]
# this is working and here is the indices [np.int64(112), np.int64(112), np.int64(112), np.int64(112)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(112), np.int64(112), np.int64(112), np.int64(112)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(117), np.int64(114), np.int64(114), np.int64(455)]
# this is working and here is the indices [np.int64(117), np.int64(114), np.int64(114), np.int64(455)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
#   2%|▉                                     | 235/10000 [00:00<00:22, 430.51it/s]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(112), np.int64(112), np.int64(112), np.int64(112)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(117), np.int64(114), np.int64(114), np.int64(455)]
# this is working and here is the indices [np.int64(117), np.int64(114), np.int64(114), np.int64(455)]
# this is working and here is the indices [np.int64(117), np.int64(114), np.int64(114), np.int64(455)]
# this is working and here is the indices [np.int64(117), np.int64(114), np.int64(114), np.int64(455)]
# this is working and here is the indices [np.int64(117), np.int64(114), np.int64(114), np.int64(455)]
# this is working and here is the indices [np.int64(117), np.int64(114), np.int64(114), np.int64(455)]
# this is working and here is the indices [np.int64(117), np.int64(114), np.int64(114), np.int64(455)]
# this is working and here is the indices [np.int64(117), np.int64(114), np.int64(114), np.int64(455)]
# this is working and here is the indices [np.int64(117), np.int64(114), np.int64(114), np.int64(455)]
# this is working and here is the indices [np.int64(117), np.int64(114), np.int64(114), np.int64(455)]
# this is working and here is the indices [np.int64(117), np.int64(114), np.int64(114), np.int64(455)]
# this is working and here is the indices [np.int64(117), np.int64(114), np.int64(114), np.int64(455)]
# this is working and here is the indices [np.int64(117), np.int64(114), np.int64(114), np.int64(455)]
# this is working and here is the indices [np.int64(117), np.int64(114), np.int64(114), np.int64(455)]
# this is working and here is the indices [np.int64(117), np.int64(114), np.int64(114), np.int64(455)]
# this is working and here is the indices [np.int64(117), np.int64(114), np.int64(114), np.int64(455)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(339), np.int64(339), np.int64(402), np.int64(339)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(112), np.int64(112), np.int64(112), np.int64(112)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
#   3%|█▎                                    | 332/10000 [00:00<00:21, 456.48it/s]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(339), np.int64(339), np.int64(402), np.int64(339)]
# this is working and here is the indices [np.int64(339), np.int64(339), np.int64(402), np.int64(339)]
# this is working and here is the indices [np.int64(339), np.int64(339), np.int64(402), np.int64(339)]
# this is working and here is the indices [np.int64(339), np.int64(339), np.int64(402), np.int64(339)]
# this is working and here is the indices [np.int64(339), np.int64(339), np.int64(402), np.int64(339)]
# this is working and here is the indices [np.int64(339), np.int64(339), np.int64(402), np.int64(339)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(112), np.int64(112), np.int64(112), np.int64(112)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(112), np.int64(112), np.int64(112), np.int64(112)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(80), np.int64(81), np.int64(80), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(112), np.int64(112), np.int64(112), np.int64(112)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(117), np.int64(114), np.int64(114), np.int64(455)]
# this is working and here is the indices [np.int64(117), np.int64(114), np.int64(114), np.int64(455)]
#   4%|█▋                                    | 437/10000 [00:00<00:19, 487.11it/s]
# this is working and here is the indices [np.int64(117), np.int64(114), np.int64(114), np.int64(455)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(117), np.int64(114), np.int64(114), np.int64(455)]
# this is working and here is the indices [np.int64(117), np.int64(114), np.int64(114), np.int64(455)]
# this is working and here is the indices [np.int64(117), np.int64(114), np.int64(114), np.int64(455)]
# this is working and here is the indices [np.int64(117), np.int64(114), np.int64(114), np.int64(455)]
# this is working and here is the indices [np.int64(117), np.int64(114), np.int64(114), np.int64(455)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(169), np.int64(87), np.int64(286), np.int64(87)]
# this is working and here is the indices [np.int64(169), np.int64(87), np.int64(286), np.int64(87)]
# this is working and here is the indices [np.int64(87), np.int64(87), np.int64(87), np.int64(87)]
# this is working and here is the indices [np.int64(112), np.int64(112), np.int64(112), np.int64(112)]
# this is working and here is the indices [np.int64(112), np.int64(112), np.int64(112), np.int64(112)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(271)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(271), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(272), np.int64(412), np.int64(272), np.int64(80)]
# this is working and here is the indices [np.int64(80), np.int64(81), np.int64(80), np.int64(80)]
# ...
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(38), np.int64(54), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(287), np.int64(87), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(287), np.int64(87), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(258), np.int64(258), np.int64(258), np.int64(258)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(287), np.int64(87), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(38), np.int64(54), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(261), np.int64(261), np.int64(261), np.int64(261)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(261), np.int64(261), np.int64(261), np.int64(261)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# 100%|████████████████████████████████████| 10000/10000 [00:20<00:00, 481.10it/s]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(245), np.int64(245), np.int64(245), np.int64(207)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(38), np.int64(54), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(70), np.int64(87), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(259), np.int64(259), np.int64(256), np.int64(256)]
# this is working and here is the indices [np.int64(24), np.int64(24), np.int64(63), np.int64(87)]
# this is working and here is the indices [np.int64(258), np.int64(258), np.int64(258), np.int64(258)]
# this is working and here is the indices [np.int64(259), np.int64(259), np.int64(256), np.int64(256)]

# %%
len(b_eq)
# Out:
# 10000

# %%
b_eq
# Out:
# array(['(GE*Exp((-1.349)+(1.98*LOG(([d130])))+ (0.207*(LOG(([d130])**2))+(-0.0281*(LOG(([d130])**3))))))',
#        '(Exp(-3.139)*[d130]**2.585)', '(Exp(-2.818)*[d130]**2.574)', ...,
#        'Exp(-2.27)*([d130]**2.39)', '(Exp(-3.416)*[d130]**2.715)',
#        '(Exp(-2.084)*[d130]**2.323)'], dtype=object)

# %%
(b_eq['grado_putrefaccion']).idxmin()
# Out:
# /tmp/ipykernel_14778/303704464.py:1: FutureWarning: The behavior of Series.idxmin with all-NA values, or any-NA and skipna=False, is deprecated. In a future version this will raise ValueError
#   (b_eq['grado_putrefaccion']).idxmin()
# nan

# %%
def count_variables(expression):
    potential_vars = re.findall(r'\b[a-zA-Z_]\w*\b', expression)
    functions_and_constants = {'Exp', 'LN'}
    variables = [var for var in potential_vars if var not in functions_and_constants]
    unique_variables = set(variables)
    return len(unique_variables)

variable_counts = b_eq['ecuacion'].apply(count_variables)

# Find the index of the row with the maximum number of variables
max_variable_index = variable_counts.idxmax()


rango = (b_eq['diametro_max'] - b_eq['diametro_min']).idxmin()
radio = (b_eq['r2']).idxmax()
arboles = (b_eq['numero_arboles']).idxmax()
variables = max_variable_index
if not np.isnan(rango):
    return b_eq.loc[rango]
elif not np.isnan(radio):
    return b_eq.loc[radio]
elif not np.isnan(arboles):
    return b_eq.loc[arboles]
elif not np.isnan(variables):
    return b_eq.iloc[variables]
else:
    return "This does not have eq that match the conditions"

# %%
def find_max_criteria_row(df):
    """
    Finds the row in the DataFrame `df` that satisfies the maximum or minimum criteria for 
    several specific columns. It checks for the following criteria in order:
    
    1. The minimum difference between 'diametro_max' and 'diametro_min'.
    2. The maximum value in the 'r2' column.
    3. The maximum value in the 'numero_arboles' column.
    4. The maximum number of unique variables in the 'ecuacion' column.
    
    The function returns the first row that satisfies any of these criteria.

    Parameters:
    ----------
    df : pandas.DataFrame
        The DataFrame containing the columns 'diametro_max', 'diametro_min', 'r2', 'numero_arboles', 
        and 'ecuacion'.

    Returns:
    -------
    pandas.Series or str
        The row from the DataFrame that meets the first of the specified criteria.
        If no criteria are met, it returns a message indicating no matches.
    """

    def count_variables(expression):
        """
        Counts the number of unique variables in a mathematical expression.

        Parameters:
        ----------
        expression : str
            The mathematical expression as a string.

        Returns:
        -------
        int
            The number of unique variables in the expression.
        """
        potential_vars = re.findall(r'\b[a-zA-Z_]\w*\b', expression)
        functions_and_constants = {'Exp', 'LN'}
        variables = [var for var in potential_vars if var not in functions_and_constants]
        unique_variables = set(variables)
        return len(unique_variables)

    # Calculate variable counts for each row in the 'ecuacion' column
    variable_counts = df['ecuacion'].apply(count_variables)

    # Find indices for the specified criteria
    indices = [
        (df['diametro_max'] - df['diametro_min']).idxmin(),  # Minimum range
        df['r2'].idxmax(),                                   # Maximum r2
        df['numero_arboles'].idxmax(),                       # Maximum number of trees
        variable_counts.idxmax()                             # Maximum variables
    ]

    # Iterate over indices and return the first valid row
    for index in indices:
        if not np.isnan(index):
            return df.loc[index]

    # If no valid index is found, return a message
    return "This does not have eq that match the conditions"

# %%
# Example usage with a DataFrame b_eq
result = find_max_criteria_row(b_eq)
print(result)
# Out:
# id                                                                  118
# id_anterior                                                       112.0
# variable_resultado                                                    b
# tipo                                                            General
# ecuacion              (GE*Exp((-1.349)+(1.98*LN((d130)))+ (0.207*(LN...
# ecuacion_php          (GE*Exp((-1.349)+(1.98*LOG(([d130])))+ (0.207*...
# especie_id                                                          NaN
# familia                                                             NaN
# genero                                                              NaN
# epiteto                                                             NaN
# condicion                                                          Vivo
# componente                                                Todo el árbol
# diametro_min                                                        5.0
# diametro_max                                                       42.0
# numero_arboles                                                    415.0
# r2                                                                 0.95
# anio_publicacion                                                 2005.0
# grado_putrefaccion                                                  NaN
# clave_ecoregion_n1                                                  NaN
# clave_ecoregion_n2                                                  NaN
# clave_ecoregion_n3                                                  NaN
# clave_ecoregion_n4                                                  NaN
# clave_bur                                                           NaN
# clave_estado_inegi                                                  NaN
# activo                                                                0
# id_especie_mn                                                       NaN
# id_modelo_mn                                                      254.0
# referencia                                             Ecuaciones Rojas
# id_referencia                                                     102.0
# notas                 Se depuraron las ecuaciones generales, mas aba...
# Name: 117, dtype: object

# %%
#c_eq = assign_equations(df_original, modelos, variable_resultado="c", conditions="carbono")
#p_eq = assign_equations(df_original, modelos, variable_resultado="p", conditions="densidad")

#df_original_muerto = df_original[df_original.condicion == "Muertos"]
#df_original_tocon = df_original[df_original.condicion == "Tocón"]

#v_eq = volumen(df_original_muerto, df_original_tocon, modelos)


np.save('b_eq.npy', b_eq)
