# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
import math 
from tqdm import tqdm

# %%
pd.set_option('display.max_columns', None)

# %%
r = '/home/gomosak/Downloads/Estimación_20 (1)/Estimación_2012-2014.csv'

# %%
df = pd.read_csv(r)

# %%
df
# Out:
#                desposito_ipcc_1        desposito_ipcc_2  \
# 0       Materia Organica Muerta           Madera muerta
# 1       Materia Organica Muerta           Madera muerta
# 2       Materia Organica Muerta           Madera muerta
# 3       Materia Organica Muerta           Madera muerta
# 4       Materia Organica Muerta           Madera muerta
# ...                         ...                     ...
# 708364             Biomasa Viva  Biomasa sobre el suelo
# 708365             Biomasa Viva  Biomasa sobre el suelo
# 708366             Biomasa Viva  Biomasa sobre el suelo
# 708367             Biomasa Viva  Biomasa sobre el suelo
# 708368             Biomasa Viva  Biomasa sobre el suelo
#
#               desposito_ipcc_3  numero_conglomerado seccion_infys  \
# 0         Madera muerta en pie                 3667      Arbolado
# 1         Madera muerta en pie                 4548      Arbolado
# 2         Madera muerta en pie                 5226      Arbolado
# ...
