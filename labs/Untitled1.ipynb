# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from collections import Counter
import math 
from tqdm import tqdm

# %%
pd.set_option('display.max_columns', None)

# %%
arboles = '../regression__head.csv'
df = pd.read_csv(arboles)

# %%
df
# Out:
#             id  anio_levantamiento  conglomerado  sitio condicion  especie_id  \
# 0       209385                2007         26005      3      Vivo     32764.0
# 1       209386                2005         26008      1      Vivo     27679.0
# 2       209387                2005         26008      1    Muerto         NaN
# 3       209388                2005         26008      1      Vivo     27679.0
# 4       209389                2005         26008      1      Vivo     12141.0
# ...        ...                 ...           ...    ...       ...         ...
# 190612  399997                2005         42006      2      Vivo      9117.0
# 190613  399998                2005         42006      2      Vivo     20695.0
# 190614  399999                2005         42006      2      Vivo     14976.0
# 190615  400000                2005         42006      2      Vivo     11795.0
# 190616  400001                2005         42006      2      Vivo     14976.0
#
#               familia       genero      epiteto categoria_infra infraespecie  \
# 0            Fagaceae      Quercus      viminea             NaN          NaN
# 1            Fagaceae      Quercus       rugosa             NaN          NaN
# 2                 NaN          NaN          NaN             NaN          NaN
# 3            Fagaceae      Quercus       rugosa             NaN          NaN
# 4            Pinaceae        Pinus  engelmannii             NaN          NaN
# ...               ...          ...          ...             ...          ...
# 190612  Euphorbiaceae     Jatropha      cinerea             NaN          NaN
# 190613    Burseraceae      Bursera  microphylla             NaN          NaN
# 190614      Cactaceae  Stenocereus     gummosus             NaN          NaN
# 190615  Anacardiaceae   Cyrtocarpa       edulis             NaN          NaN
# 190616      Cactaceae  Stenocereus     gummosus             NaN          NaN
#
#         numero_arbol  numero_tallo  tallos   diametro  altura  is_predicted  \
# 0                 34           NaN     NaN  22.432915    10.0           2.0
# 1                  1           NaN     NaN  50.000000    18.0           0.0
# 2                  2           NaN     NaN  30.000000    14.0           0.0
# 3                  3           NaN     NaN  51.000000    24.0           0.0
# 4                  4           NaN     NaN  49.000000    30.0           0.0
# ...              ...           ...     ...        ...     ...           ...
# 190612            10           NaN     2.0   9.750000     3.2           0.0
# 190613            11           NaN     3.0  13.160000     3.2           0.0
# 190614            12           NaN     2.0  14.918069     2.2           2.0
# 190615            13           NaN     2.0  10.200000     3.6           0.0
# 190616            14           NaN     2.0  14.543258     1.9           2.0
#
#           latitud    longitud  clave_ecoregion_n2 clave_bur  \
# 0       26.446588 -107.546118                13.2       BCO
# 1       26.453921 -107.394921                13.2       BCO
# 2       26.453921 -107.394921                13.2       BCO
# 3       26.453921 -107.394921                13.2       BCO
# 4       26.453921 -107.394921                13.2       BCO
# ...           ...         ...                 ...       ...
# 190612  23.187752 -109.523006                14.6       MXL
# 190613  23.187752 -109.523006                14.6       MXL
# 190614  23.187752 -109.523006                14.6       MXL
# 190615  23.187752 -109.523006                14.6       MXL
# 190616  23.187752 -109.523006                14.6       MXL
#
#                            referencia_1  referencia_2  user_id  \
# 0               caracteristica_arbolado        194534      1.0
# 1               caracteristica_arbolado        194542      1.0
# 2               caracteristica_arbolado        194543      1.0
# 3               caracteristica_arbolado        194544      1.0
# 4               caracteristica_arbolado        194545      1.0
# ...                                 ...           ...      ...
# 190612  caracteristica_vegetacion_mayor         87500      1.0
# 190613  caracteristica_vegetacion_mayor         87501      1.0
# 190614  caracteristica_vegetacion_mayor         87502      1.0
# 190615  caracteristica_vegetacion_mayor         87503      1.0
# 190616  caracteristica_vegetacion_mayor         87504      1.0
#
#                      created_at               updated_at  grado_putrefaccion  \
# 0       2019-11-14 20:24:49.070  2019-11-14 20:24:49.070                 NaN
# 1       2019-11-14 20:24:49.070  2019-11-14 20:24:49.070                 NaN
# 2       2019-11-14 20:24:49.070  2019-11-14 20:24:49.070                 NaN
# 3       2019-11-14 20:24:49.070  2019-11-14 20:24:49.070                 NaN
# 4       2019-11-14 20:24:49.070  2019-11-14 20:24:49.070                 NaN
# ...                         ...                      ...                 ...
# 190612  2019-11-14 20:24:49.070  2019-11-14 20:24:49.070                 NaN
# 190613  2019-11-14 20:24:49.070  2019-11-14 20:24:49.070                 NaN
# 190614  2019-11-14 20:24:49.070  2019-11-14 20:24:49.070                 NaN
# 190615  2019-11-14 20:24:49.070  2019-11-14 20:24:49.070                 NaN
# 190616  2019-11-14 20:24:49.070  2019-11-14 20:24:49.070                 NaN
#
#         clave_ecoregion_n1 clave_ecoregion_n3 clave_ecoregion_n4  \
# 0                       13             13.2.1           13.2.1.1
# 1                       13             13.2.1           13.2.1.1
# 2                       13             13.2.1           13.2.1.1
# 3                       13             13.2.1           13.2.1.1
# 4                       13             13.2.1           13.2.1.1
# ...                    ...                ...                ...
# 190612                  14             14.6.1           14.6.1.1
# 190613                  14             14.6.1           14.6.1.1
# 190614                  14             14.6.1           14.6.1.1
# 190615                  14             14.6.1           14.6.1.1
# 190616                  14             14.6.1           14.6.1.1
#
#         estado_inegi               estado   edad
# 0                  8            Chihuahua    NaN
# 1                  8            Chihuahua    NaN
# 2                  8            Chihuahua    NaN
# 3                  8            Chihuahua    NaN
# 4                  8            Chihuahua  152.0
# ...              ...                  ...    ...
# 190612             3  Baja California Sur    NaN
# 190613             3  Baja California Sur    NaN
# 190614             3  Baja California Sur    NaN
# 190615             3  Baja California Sur    NaN
# 190616             3  Baja California Sur    NaN
#
# [190617 rows x 33 columns]

# %%
x = resulado.plot(kind='scatter', x='biomasa', y='carbono', label='Data Points')

# Now, use matplotlib's plot and axhline directly
# Plot the line x = y
plt.plot([x / 2 for x in range(len(df))],range(len(df)), color='red', label='x = y')

# Plot the line x = y
#ax.plot(range(1000),range(1000), color='red', label='x = y')
# Add labels and title
plt.xlabel('biomasa Label')
plt.ylabel('carbono Label')
plt.title('Plot of Two Columns')
plt.show()

# %%
arboles = '../out.csv'
df = pd.read_csv(arboles)

# %%
df
# Out:
#             id  anio_levantamiento  conglomerado  sitio condicion  especie_id  \
# 0       209385                2007         26005      3      Vivo     32764.0
# 1       209386                2005         26008      1      Vivo     27679.0
# 2       209387                2005         26008      1    Muerto         NaN
# 3       209388                2005         26008      1      Vivo     27679.0
# 4       209389                2005         26008      1      Vivo     12141.0
# ...        ...                 ...           ...    ...       ...         ...
# 190612  399997                2005         42006      2      Vivo      9117.0
# 190613  399998                2005         42006      2      Vivo     20695.0
# 190614  399999                2005         42006      2      Vivo     14976.0
# 190615  400000                2005         42006      2      Vivo     11795.0
# 190616  400001                2005         42006      2      Vivo     14976.0
#
#               familia       genero      epiteto categoria_infra infraespecie  \
# 0            Fagaceae      Quercus      viminea             NaN          NaN
# 1            Fagaceae      Quercus       rugosa             NaN          NaN
# 2                 NaN          NaN          NaN             NaN          NaN
# 3            Fagaceae      Quercus       rugosa             NaN          NaN
# 4            Pinaceae        Pinus  engelmannii             NaN          NaN
# ...               ...          ...          ...             ...          ...
# 190612  Euphorbiaceae     Jatropha      cinerea             NaN          NaN
# 190613    Burseraceae      Bursera  microphylla             NaN          NaN
# 190614      Cactaceae  Stenocereus     gummosus             NaN          NaN
# 190615  Anacardiaceae   Cyrtocarpa       edulis             NaN          NaN
# 190616      Cactaceae  Stenocereus     gummosus             NaN          NaN
#
#         numero_arbol  numero_tallo  tallos   diametro  altura  is_predicted  \
# 0                 34           NaN     NaN  22.432915    10.0           2.0
# 1                  1           NaN     NaN  50.000000    18.0           0.0
# 2                  2           NaN     NaN  30.000000    14.0           0.0
# 3                  3           NaN     NaN  51.000000    24.0           0.0
# 4                  4           NaN     NaN  49.000000    30.0           0.0
# ...              ...           ...     ...        ...     ...           ...
# 190612            10           NaN     2.0   9.750000     3.2           0.0
# 190613            11           NaN     3.0  13.160000     3.2           0.0
# 190614            12           NaN     2.0  14.918069     2.2           2.0
# 190615            13           NaN     2.0  10.200000     3.6           0.0
# 190616            14           NaN     2.0  14.543258     1.9           2.0
#
#           latitud    longitud  clave_ecoregion_n2 clave_bur  \
# 0       26.446588 -107.546118                13.2       BCO
# 1       26.453921 -107.394921                13.2       BCO
# 2       26.453921 -107.394921                13.2       BCO
# 3       26.453921 -107.394921                13.2       BCO
# 4       26.453921 -107.394921                13.2       BCO
# ...           ...         ...                 ...       ...
# 190612  23.187752 -109.523006                14.6       MXL
# 190613  23.187752 -109.523006                14.6       MXL
# 190614  23.187752 -109.523006                14.6       MXL
# 190615  23.187752 -109.523006                14.6       MXL
# 190616  23.187752 -109.523006                14.6       MXL
#
#                            referencia_1  referencia_2  user_id  \
# 0               caracteristica_arbolado        194534      1.0
# 1               caracteristica_arbolado        194542      1.0
# 2               caracteristica_arbolado        194543      1.0
# 3               caracteristica_arbolado        194544      1.0
# 4               caracteristica_arbolado        194545      1.0
# ...                                 ...           ...      ...
# 190612  caracteristica_vegetacion_mayor         87500      1.0
# 190613  caracteristica_vegetacion_mayor         87501      1.0
# 190614  caracteristica_vegetacion_mayor         87502      1.0
# 190615  caracteristica_vegetacion_mayor         87503      1.0
# 190616  caracteristica_vegetacion_mayor         87504      1.0
#
#                      created_at               updated_at  grado_putrefaccion  \
# 0       2019-11-14 20:24:49.070  2019-11-14 20:24:49.070                 NaN
# 1       2019-11-14 20:24:49.070  2019-11-14 20:24:49.070                 NaN
# 2       2019-11-14 20:24:49.070  2019-11-14 20:24:49.070                 NaN
# 3       2019-11-14 20:24:49.070  2019-11-14 20:24:49.070                 NaN
# 4       2019-11-14 20:24:49.070  2019-11-14 20:24:49.070                 NaN
# ...                         ...                      ...                 ...
# 190612  2019-11-14 20:24:49.070  2019-11-14 20:24:49.070                 NaN
# 190613  2019-11-14 20:24:49.070  2019-11-14 20:24:49.070                 NaN
# 190614  2019-11-14 20:24:49.070  2019-11-14 20:24:49.070                 NaN
# 190615  2019-11-14 20:24:49.070  2019-11-14 20:24:49.070                 NaN
# 190616  2019-11-14 20:24:49.070  2019-11-14 20:24:49.070                 NaN
#
#         clave_ecoregion_n1 clave_ecoregion_n3 clave_ecoregion_n4  \
# 0                       13             13.2.1           13.2.1.1
# 1                       13             13.2.1           13.2.1.1
# 2                       13             13.2.1           13.2.1.1
# 3                       13             13.2.1           13.2.1.1
# 4                       13             13.2.1           13.2.1.1
# ...                    ...                ...                ...
# 190612                  14             14.6.1           14.6.1.1
# 190613                  14             14.6.1           14.6.1.1
# 190614                  14             14.6.1           14.6.1.1
# 190615                  14             14.6.1           14.6.1.1
# 190616                  14             14.6.1           14.6.1.1
#
#         estado_inegi               estado   edad     carbon_eq  \
# 0                  8            Chihuahua    NaN  (0.4726*[b])
# 1                  8            Chihuahua    NaN      [b]*0.46
# 2                  8            Chihuahua    NaN     [b]*0.447
# 3                  8            Chihuahua    NaN      [b]*0.46
# 4                  8            Chihuahua  152.0      [b]*0.49
# ...              ...                  ...    ...           ...
# 190612             3  Baja California Sur    NaN     [b]*0.447
# 190613             3  Baja California Sur    NaN      [b]*0.44
# 190614             3  Baja California Sur    NaN     [b]*0.447
# 190615             3  Baja California Sur    NaN    [b]*0.4501
# 190616             3  Baja California Sur    NaN     [b]*0.447
#
#                                                biomasa_eq  densidad_eq  \
# 0                             (Exp(-2.754)*[d130]**2.574)      0.64693
# 1                     (0.283)*((([d130]**2)*[ht])**0.807)      0.65041
# 2        (3.14159 * (([d130] / 2 / 100) ** 2) * [ht]) / 3      0.56366
# 3                     (0.283)*((([d130]**2)*[ht])**0.807)      0.65041
# 4                               (0.1354)*([d130]**2.3033)      0.44181
# ...                                                   ...          ...
# 190612  (Exp(-2.187+(0.916*(LOG(([p])*(([d130])**2)*([...      0.30697
# 190613                            (0.0841)*([d130]**2.41)      0.35798
# 190614  (Exp(-2.187+(0.916*(LOG(([p])*(([d130])**2)*([...      0.50012
# 190615  (Exp(-2.187+(0.916*(LOG(([p])*(([d130])**2)*([...      0.50074
# 190616  (Exp(-2.187+(0.916*(LOG(([p])*(([d130])**2)*([...      0.50012
#
#                                               volumen_eq
# 0                                                    NaN
# 1                                                    NaN
# 2       (3.14159 * (([d130] / 2 / 100) ** 2) * [ht]) / 3
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 190612                                               NaN
# 190613                                               NaN
# 190614                                               NaN
# 190615                                               NaN
# 190616                                               NaN
#
# [190617 rows x 37 columns]
