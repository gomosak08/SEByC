# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("../csvs/arboles.csv")
# Out:
# /tmp/ipykernel_15268/2549471356.py:1: DtypeWarning: Columns (9,10,20,23,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../csvs/arboles.csv")

# %%
df.head()
# Out:
#    id  anio_levantamiento  conglomerado  sitio condicion  especie_id  \
# 0   1                2005            60      1      Vivo       680.0
# 1   2                2005            64      4      Vivo     26426.0
# 2   3                2005           153      1      Vivo     26426.0
# 3   4                2005           153      1      Vivo     26426.0
# 4   5                2005           153      1      Vivo     26426.0
#
#      familia          genero      epiteto categoria_infra infraespecie  \
# 0  Ericaceae  Arctostaphylos          NaN             NaN          NaN
# 1   Pinaceae           Pinus  quadrifolia             NaN          NaN
# 2   Pinaceae           Pinus  quadrifolia             NaN          NaN
# 3   Pinaceae           Pinus  quadrifolia             NaN          NaN
# 4   Pinaceae           Pinus  quadrifolia             NaN          NaN
#
#    numero_arbol  numero_tallo  tallos  diametro  altura    latitud  \
# ...

# %%
df3 = df[(df.anio_levantamiento >= 2004) & (df.anio_levantamiento <= 2008)]

# %%
df3.head()
# Out:
#    id  anio_levantamiento  conglomerado  sitio condicion  especie_id  \
# 0   1                2005            60      1      Vivo       680.0
# 1   2                2005            64      4      Vivo     26426.0
# 2   3                2005           153      1      Vivo     26426.0
# 3   4                2005           153      1      Vivo     26426.0
# 4   5                2005           153      1      Vivo     26426.0
#
#      familia          genero      epiteto categoria_infra infraespecie  \
# 0  Ericaceae  Arctostaphylos          NaN             NaN          NaN
# 1   Pinaceae           Pinus  quadrifolia             NaN          NaN
# 2   Pinaceae           Pinus  quadrifolia             NaN          NaN
# 3   Pinaceae           Pinus  quadrifolia             NaN          NaN
# 4   Pinaceae           Pinus  quadrifolia             NaN          NaN
#
#    numero_arbol  numero_tallo  tallos  diametro  altura    latitud  \
# ...

# %%
df3
# Out:
#             id  anio_levantamiento  conglomerado  sitio condicion  especie_id  \
# 0            1                2005            60      1      Vivo       680.0
# 1            2                2005            64      4      Vivo     26426.0
# 2            3                2005           153      1      Vivo     26426.0
# 3            4                2005           153      1      Vivo     26426.0
# 4            5                2005           153      1      Vivo     26426.0
# ...        ...                 ...           ...    ...       ...         ...
# 99996    99997                2005         14554      2      Vivo     16165.0
# 99997    99998                2005         14554      2      Vivo     16165.0
# 99998    99999                2005         14554      2      Vivo     16165.0
# 99999   100000                2005         14554      2      Vivo     32764.0
# 100000  100001                2005         14554      2    Muerto     33449.0
#
# ...

# %%
df3.to_csv("arboles_1000_head.csv",index=False)

# %%
df3[df3.condicion == "Tocón"]
# Out:
#       id  anio_levantamiento  conglomerado  sitio condicion  especie_id  \
# 15    16                2005           153      1     Tocón      2270.0
# 47    48                2004           154      2     Tocón     21121.0
# 70    71                2005           155      3     Tocón      4135.0
# 71    72                2005           155      3     Tocón      4135.0
# 74    75                2005           155      3     Tocón      4135.0
# 75    76                2005           155      3     Tocón      4135.0
# 76    77                2005           155      3     Tocón      4135.0
# 627  628                2005           526      4     Tocón     16945.0
# 628  629                2005           526      4     Tocón     16945.0
# 630  631                2005           526      4     Tocón     16945.0
# 631  632                2005           526      4     Tocón     16945.0
# 632  633                2005           526      4     Tocón     16945.0
# ...

# %%
a = df3.loc[0]
a
# Out:
# id                                                  1
# anio_levantamiento                               2005
# conglomerado                                       60
# sitio                                               1
# condicion                                        Vivo
# especie_id                                      680.0
# familia                                     Ericaceae
# genero                                 Arctostaphylos
# epiteto                                           NaN
# categoria_infra                                   NaN
# infraespecie                                      NaN
# numero_arbol                                        1
# numero_tallo                                      NaN
# tallos                                            3.0
# diametro                                          8.3
# altura                                            3.2
# latitud                                     32.515597
# ...

# %%
np.isnan(a.edad)
# Out:
# np.True_

# %%
pd.isnull(a.estado)
# Out:
# False

# %%
len(df3)
# Out:
# 1001

# %%
df = pd.read_csv("out.csv")
# Out:
# /tmp/ipykernel_7706/3238720368.py:1: DtypeWarning: Columns (11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("out.csv")

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0         id  anio_levantamiento  conglomerado  \
# 0             0   2886148.0  2886174.0              2016.0       50760.0
# 1             1   2886149.0  2886175.0              2016.0       50760.0
# 2             2   2886150.0  2886176.0              2016.0       50760.0
# 3             3   2886151.0  2886177.0              2016.0       50760.0
# 4             4   2886152.0  2886178.0              2016.0       50760.0
#
#    sitio condicion  especie_id        familia       genero         epiteto  \
# 0    1.0      Vivo         NaN      Malvaceae       Hampea       trilobata
# 1    1.0      Vivo         NaN  Nyctaginaceae         Neea  psychotrioides
# 2    1.0      Vivo         NaN       Fabaceae     Lysiloma    latisiliquum
# 3    1.0      Vivo         NaN      Malvaceae       Luehea        speciosa
# 4    1.0      Vivo         NaN     Sapotaceae  Sideroxylon    salicifolium
#
# ...

# %%
df.is_predicted.value_counts()
# Out:
# is_predicted
# 0.0    831331
# Name: count, dtype: int64

# %%
df.is_predicted.value_counts()
# Out:
# is_predicted
# 0.0    797404
# 2.0     12800
# 1.0      1413
# Name: count, dtype: int64

# %%
df.anio_levantamiento.value_counts().sort_values()
# Out:
# anio_levantamiento
# 2004     57198
# 2018     70822
# 2017     97781
# 2014    124222
# 2019    137663
# 2007    220566
# 2016    257073
# 2015    267992
# 2009    278312
# 2013    291158
# 2011    293027
# 2010    295597
# 2012    298702
# 2006    349929
# 2005    677437
# Name: count, dtype: int64

# %%
df3 = df[(df.anio_levantamiento >= 2015) & (df.anio_levantamiento <= 2020)]

# %%
ciclo1 = df[(df.anio_levantamiento >= 2005) & (df.anio_levantamiento <= 2008)]

# %%
ciclo1.to_csv("csvs/ciclo_1.csv",index=False)
