# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("../csvs/arboles.csv")
# Out:
# /tmp/ipykernel_62419/2549471356.py:1: DtypeWarning: Columns (9,10,20,23,24) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("../csvs/arboles.csv")

# %%
df.head()
# Out:
#    id  anio_levantamiento  conglomerado  sitio condicion  especie_id  \
# 0   1                2005            60      1      Vivo       680.0
# 1   2                2005            64      4      Vivo     26426.0
# 2   3                2005           153      1      Vivo     26426.0
# 3   4                2005           153      1      Vivo     26426.0
# 4   5                2005           153      1      Vivo     26426.0
#
#      familia          genero      epiteto categoria_infra infraespecie  \
# 0  Ericaceae  Arctostaphylos          NaN             NaN          NaN
# 1   Pinaceae           Pinus  quadrifolia             NaN          NaN
# 2   Pinaceae           Pinus  quadrifolia             NaN          NaN
# 3   Pinaceae           Pinus  quadrifolia             NaN          NaN
# 4   Pinaceae           Pinus  quadrifolia             NaN          NaN
#
#    numero_arbol  numero_tallo  tallos  diametro  altura    latitud  \
# 0             1           NaN     3.0       8.3    3.20  32.515597
# 1             1           NaN     0.0      14.0    5.50  32.532903
# 2             1           NaN     NaN      17.0    5.50  32.448351
# 3             2           NaN     NaN      14.5    5.85  32.448351
# 4             3           NaN     NaN      21.0    6.25  32.448351
#
#      longitud  clave_ecoregion_n2 clave_bur                     referencia_1  \
# 0 -116.350450                11.1       MXL  caracteristica_vegetacion_mayor
# 1 -116.140585                11.1       MXL  caracteristica_vegetacion_mayor
# 2 -116.077138                11.1       BCO          caracteristica_arbolado
# 3 -116.077138                11.1       BCO          caracteristica_arbolado
# 4 -116.077138                11.1       BCO          caracteristica_arbolado
#
#    referencia_2  user_id               created_at               updated_at  \
# 0        107497      1.0  2019-11-14 20:24:49.070  2019-11-14 20:24:49.070
# 1        101063      1.0  2019-11-14 20:24:49.070  2019-11-14 20:24:49.070
# 2             1      1.0  2019-11-14 20:24:49.070  2019-11-14 20:24:49.070
# 3             2      1.0  2019-11-14 20:24:49.070  2019-11-14 20:24:49.070
# 4             3      1.0  2019-11-14 20:24:49.070  2019-11-14 20:24:49.070
#
#    grado_putrefaccion  clave_ecoregion_n1 clave_ecoregion_n3  \
# 0                 NaN                  11             11.1.1
# 1                 NaN                  11             11.1.1
# 2                 NaN                  11             11.1.3
# 3                 NaN                  11             11.1.3
# 4                 NaN                  11             11.1.3
#
#   clave_ecoregion_n4  estado_inegi           estado  edad
# 0           11.1.1.3             2  Baja California   NaN
# 1           11.1.1.3             2  Baja California   NaN
# 2           11.1.3.1             2  Baja California  74.0
# 3           11.1.3.1             2  Baja California  61.0
# 4           11.1.3.1             2  Baja California   NaN

# %%
df.set_index('id', inplace=True)

# %%
df3 = df.loc[[3715834,3715971,3715996,3716061]]

# %%
df3 = df[(df.anio_levantamiento >= 2015) & (df.anio_levantamiento <= 2020)]

# %%
df3.head()
# Out:
#               id  anio_levantamiento  conglomerado  sitio condicion  \
# 2886148  2886174                2016         50760      1      Vivo
# 2886149  2886175                2016         50760      1      Vivo
# 2886150  2886176                2016         50760      1      Vivo
# 2886151  2886177                2016         50760      1      Vivo
# 2886152  2886178                2016         50760      1      Vivo
#
#          especie_id        familia       genero         epiteto  \
# 2886148         NaN      Malvaceae       Hampea       trilobata
# 2886149         NaN  Nyctaginaceae         Neea  psychotrioides
# 2886150         NaN       Fabaceae     Lysiloma    latisiliquum
# 2886151         NaN      Malvaceae       Luehea        speciosa
# 2886152         NaN     Sapotaceae  Sideroxylon    salicifolium
#
#         categoria_infra infraespecie  numero_arbol  numero_tallo  tallos  \
# 2886148             NaN          NaN            14          16.0     NaN
# 2886149             NaN          NaN            21          23.0     NaN
# 2886150             NaN          NaN            29          34.0     NaN
# 2886151             NaN          NaN            35          40.0     NaN
# 2886152             NaN          NaN            44          49.0     NaN
#
#          diametro  altura  latitud   longitud  clave_ecoregion_n2 clave_bur  \
# 2886148       8.3     6.4   20.622 -87.336694                15.2       SMQ
# 2886149      10.4     8.6   20.622 -87.336694                15.2       SMQ
# 2886150      32.8    10.3   20.622 -87.336694                15.2       SMQ
# 2886151       8.2     7.9   20.622 -87.336694                15.2       SMQ
# 2886152       9.8     6.8   20.622 -87.336694                15.2       SMQ
#
#         referencia_1  referencia_2  user_id created_at updated_at  \
# 2886148       493302            16      NaN        NaN        NaN
# 2886149       493309            23      NaN        NaN        NaN
# 2886150       493320            34      NaN        NaN        NaN
# 2886151       493326            40      NaN        NaN        NaN
# 2886152       493335            49      NaN        NaN        NaN
#
#          grado_putrefaccion  clave_ecoregion_n1 clave_ecoregion_n3  \
# 2886148                 NaN                  15             15.2.2
# 2886149                 NaN                  15             15.2.2
# 2886150                 NaN                  15             15.2.2
# 2886151                 NaN                  15             15.2.2
# 2886152                 NaN                  15             15.2.2
#
#         clave_ecoregion_n4  estado_inegi        estado  edad
# 2886148           15.2.2.2            23  Quintana Roo   NaN
# 2886149           15.2.2.2            23  Quintana Roo   NaN
# 2886150           15.2.2.2            23  Quintana Roo   NaN
# 2886151           15.2.2.2            23  Quintana Roo   NaN
# 2886152           15.2.2.2            23  Quintana Roo   NaN

# %%
len(df3)
# Out:
# 831331

# %%
df3.to_csv("ciclo3.csv",index=False)

# %%
df3
# Out:
#             id  anio_levantamiento  conglomerado  sitio condicion  especie_id  \
# 829660  829661                2005         57718      2      Vivo     26955.0
# 829797  829798                2005         57718      4      Vivo     26955.0
# 829822  829823                2005         57718      4      Vivo     26955.0
# 829887  829888                2005         57719      4      Vivo     12554.0
#
#             familia   genero     epiteto categoria_infra infraespecie  \
# 829660     Fagaceae  Quercus    resinosa             NaN          NaN
# 829797     Fagaceae  Quercus    resinosa             NaN          NaN
# 829822     Fagaceae  Quercus    resinosa             NaN          NaN
# 829887  Burseraceae  Bursera  fagaroides             NaN          NaN
#
#         numero_arbol  numero_tallo  tallos  diametro  altura    latitud  \
# 829660            11           NaN     NaN      14.3     6.0  19.951951
# 829797            38           NaN     NaN      12.4     8.0  19.951284
# 829822            63           NaN     NaN      10.7     7.0  19.951284
# 829887             5           NaN     NaN       7.8     2.5  19.951784
#
#           longitud  clave_ecoregion_n2 clave_bur             referencia_1  \
# 829660 -104.163748                13.4        BE  caracteristica_arbolado
# 829797 -104.164109                13.4        BE  caracteristica_arbolado
# 829822 -104.164109                13.4        BE  caracteristica_arbolado
# 829887 -104.115914                13.4        BE  caracteristica_arbolado
#
#         referencia_2  user_id               created_at  \
# 829660        792996      1.0  2019-11-14 20:24:49.070
# 829797        793146      1.0  2019-11-14 20:24:49.070
# 829822        793132      1.0  2019-11-14 20:24:49.070
# 829887        793227      1.0  2019-11-14 20:24:49.070
#
#                      updated_at  grado_putrefaccion  clave_ecoregion_n1  \
# 829660  2019-11-14 20:24:49.070                 NaN                  13
# 829797  2019-11-14 20:24:49.070                 NaN                  13
# 829822  2019-11-14 20:24:49.070                 NaN                  13
# 829887  2019-11-14 20:24:49.070                 NaN                  13
#
#        clave_ecoregion_n3 clave_ecoregion_n4  estado_inegi   estado  edad
# 829660             13.4.2           13.4.2.2            14  Jalisco   NaN
# 829797             13.4.2           13.4.2.2            14  Jalisco   NaN
# 829822             13.4.2           13.4.2.2            14  Jalisco   NaN
# 829887             13.4.2           13.4.2.2            14  Jalisco   NaN

# %%
a = df3.loc[0]
a
# Out:
# id                                                  1
# anio_levantamiento                               2005
# conglomerado                                       60
# sitio                                               1
# condicion                                        Vivo
# especie_id                                      680.0
# familia                                     Ericaceae
# genero                                 Arctostaphylos
# epiteto                                           NaN
# categoria_infra                                   NaN
# infraespecie                                      NaN
# numero_arbol                                        1
# numero_tallo                                      NaN
# tallos                                            3.0
# diametro                                          8.3
# altura                                            3.2
# latitud                                     32.515597
# longitud                                   -116.35045
# clave_ecoregion_n2                               11.1
# clave_bur                                         MXL
# referencia_1          caracteristica_vegetacion_mayor
# referencia_2                                   107497
# user_id                                           1.0
# created_at                    2019-11-14 20:24:49.070
# updated_at                    2019-11-14 20:24:49.070
# grado_putrefaccion                                NaN
# clave_ecoregion_n1                                 11
# clave_ecoregion_n3                             11.1.1
# clave_ecoregion_n4                           11.1.1.3
# estado_inegi                                        2
# estado                                Baja California
# edad                                              NaN
# Name: 0, dtype: object

# %%
np.isnan(a.edad)
# Out:
# np.True_

# %%
pd.isnull(a.estado)
# Out:
# False

# %%
len(df3)
# Out:
# 1001

# %%
df = pd.read_csv("out.csv")
# Out:
# /tmp/ipykernel_7706/3238720368.py:1: DtypeWarning: Columns (11,12) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("out.csv")

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0         id  anio_levantamiento  conglomerado  \
# 0             0   2886148.0  2886174.0              2016.0       50760.0
# 1             1   2886149.0  2886175.0              2016.0       50760.0
# 2             2   2886150.0  2886176.0              2016.0       50760.0
# 3             3   2886151.0  2886177.0              2016.0       50760.0
# 4             4   2886152.0  2886178.0              2016.0       50760.0
#
#    sitio condicion  especie_id        familia       genero         epiteto  \
# 0    1.0      Vivo         NaN      Malvaceae       Hampea       trilobata
# 1    1.0      Vivo         NaN  Nyctaginaceae         Neea  psychotrioides
# 2    1.0      Vivo         NaN       Fabaceae     Lysiloma    latisiliquum
# 3    1.0      Vivo         NaN      Malvaceae       Luehea        speciosa
# 4    1.0      Vivo         NaN     Sapotaceae  Sideroxylon    salicifolium
#
#   categoria_infra infraespecie  numero_arbol  numero_tallo  tallos  diametro  \
# 0             NaN          NaN          14.0          16.0     NaN       8.3
# 1             NaN          NaN          21.0          23.0     NaN      10.4
# 2             NaN          NaN          29.0          34.0     NaN      32.8
# 3             NaN          NaN          35.0          40.0     NaN       8.2
# 4             NaN          NaN          44.0          49.0     NaN       9.8
#
#    altura  is_predicted  latitud   longitud  clave_ecoregion_n2 clave_bur  \
# 0     6.4           0.0   20.622 -87.336694                15.2       SMQ
# 1     8.6           0.0   20.622 -87.336694                15.2       SMQ
# 2    10.3           0.0   20.622 -87.336694                15.2       SMQ
# 3     7.9           0.0   20.622 -87.336694                15.2       SMQ
# 4     6.8           0.0   20.622 -87.336694                15.2       SMQ
#
#    referencia_1  referencia_2  user_id  created_at  updated_at  \
# 0      493302.0          16.0      NaN         NaN         NaN
# 1      493309.0          23.0      NaN         NaN         NaN
# 2      493320.0          34.0      NaN         NaN         NaN
# 3      493326.0          40.0      NaN         NaN         NaN
# 4      493335.0          49.0      NaN         NaN         NaN
#
#    grado_putrefaccion  clave_ecoregion_n1 clave_ecoregion_n3  \
# 0                 NaN                15.0             15.2.2
# 1                 NaN                15.0             15.2.2
# 2                 NaN                15.0             15.2.2
# 3                 NaN                15.0             15.2.2
# 4                 NaN                15.0             15.2.2
#
#   clave_ecoregion_n4  estado_inegi        estado  edad
# 0           15.2.2.2          23.0  Quintana Roo   NaN
# 1           15.2.2.2          23.0  Quintana Roo   NaN
# 2           15.2.2.2          23.0  Quintana Roo   NaN
# 3           15.2.2.2          23.0  Quintana Roo   NaN
# 4           15.2.2.2          23.0  Quintana Roo   NaN

# %%
df.is_predicted.value_counts()
# Out:
# is_predicted
# 0.0    831331
# Name: count, dtype: int64

# %%
df.is_predicted.value_counts()
# Out:
# is_predicted
# 0.0    797404
# 2.0     12800
# 1.0      1413
# Name: count, dtype: int64

# %%
df.anio_levantamiento.value_counts().sort_values()
# Out:
# anio_levantamiento
# 2004     57198
# 2018     70822
# 2017     97781
# 2014    124222
# 2019    137663
# 2007    220566
# 2016    257073
# 2015    267992
# 2009    278312
# 2013    291158
# 2011    293027
# 2010    295597
# 2012    298702
# 2006    349929
# 2005    677437
# Name: count, dtype: int64

# %%
df3 = df[(df.anio_levantamiento >= 2015) & (df.anio_levantamiento <= 2020)]

# %%
ciclo1 = df[(df.anio_levantamiento >= 2005) & (df.anio_levantamiento <= 2008)]

# %%
ciclo1.to_csv("ciclo_1.csv",index=False)

# %%
ciclo1 = df[(df.anio_levantamiento >= 2004) & (df.anio_levantamiento <= 2007)]

# %%
ciclo1.to_csv("ciclo_1.csv",index=False)

# %%
ciclo2 = df[(df.anio_levantamiento >= 2009) & (df.anio_levantamiento <= 2014)]

# %%
ciclo2.to_csv("ciclo_2.csv",index=False)
